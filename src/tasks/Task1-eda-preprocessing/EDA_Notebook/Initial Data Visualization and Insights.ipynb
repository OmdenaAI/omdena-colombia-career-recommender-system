# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import ast

# %matplotlib inline

# %%
df = pd.read_csv("saber_combined_all_fields.csv")
df = df.drop(columns = 'Unnamed: 0')
df
# Out:
#        estu_tipodocumento estu_nacionalidad estu_genero estu_fechanacimiento  \
# 0                      TI          COLOMBIA           M           30/07/1996
# 1                      CC          COLOMBIA           M           13/04/1994
# 2                      CC          COLOMBIA           F           08/12/1991
# 3                      TI          COLOMBIA           F           10/01/1996
# 4                      CC          COLOMBIA           M           11/10/1995
# ...                   ...               ...         ...                  ...
# 212005                 CC          COLOMBIA           F           18/07/1997
# 212006                 CC          COLOMBIA           F           04/09/1995
# 212007                 CC          COLOMBIA           F           21/10/1971
# 212008                 CC          COLOMBIA           M           10/08/1994
# 212009                 CC          COLOMBIA           M           01/01/1997
#
#        estu_exterior  periodo estu_consecutivo estu_estadocivil  \
# 0                NaN    20134   EK201340233804          Soltero
# 1                NaN    20133   EK201330220754          Soltero
# 2                NaN    20134   EK201340246502          Soltero
# 3                NaN    20134   EK201340237996          Soltero
# 4                 NO    20173   EK201730119521              NaN
# ...              ...      ...              ...              ...
# 212005            NO    20183   EK201830051813          Soltero
# 212006            NO    20183   EK201830033770          Soltero
# 212007            NO    20183   EK201830110470           Casado
# 212008            NO    20183   EK201830148018          Soltero
# 212009            NO    20183   EK201830033403          Soltero
#
#        estu_estudiante estu_pais_reside  ... punt_biologia punt_quimica  \
# 0           ESTUDIANTE         COLOMBIA  ...          39.0         42.0
# 1           ESTUDIANTE         COLOMBIA  ...          52.0         52.0
# 2           ESTUDIANTE         COLOMBIA  ...          50.0         51.0
# 3           ESTUDIANTE         COLOMBIA  ...          34.0         35.0
# 4           ESTUDIANTE         COLOMBIA  ...          57.0         65.0
# ...                ...              ...  ...           ...          ...
# 212005      ESTUDIANTE         COLOMBIA  ...          49.0         54.0
# 212006      ESTUDIANTE         COLOMBIA  ...          68.0         56.0
# 212007      ESTUDIANTE         COLOMBIA  ...          43.0         29.0
# 212008      ESTUDIANTE         COLOMBIA  ...          42.0         46.0
# 212009      ESTUDIANTE         COLOMBIA  ...          57.0         61.0
#
#         punt_fisica punt_ciencias_sociales  punt_filosofia punt_ingles  \
# 0              33.0                   33.0            29.0        38.0
# 1              54.0                   44.0            47.0        51.0
# 2              28.0                   46.0            45.0        43.0
# 3              45.0                   42.0            40.0        43.0
# 4              44.0                   49.0            43.0        42.0
# ...             ...                    ...             ...         ...
# 212005         70.0                   53.0            52.0        58.0
# 212006         55.0                   60.0            42.0        75.0
# 212007         46.0                   40.0            34.0        38.0
# 212008         45.0                   44.0            33.0        43.0
# 212009         56.0                   69.0            69.0        50.0
#
#         desemp_ingles                    profundiza puntaje_prof desemp_prof
# 0                  A-  PUNT_INTERDISC_MEDIOAMBIENTE         49.0         NaN
# 1                  A1      PUNT_PROFUNDIZA_LENGUAJE          6.0          II
# 2                  A-      PUNT_PROFUNDIZA_BIOLOGIA          5.0           I
# 3                  A-  PUNT_INTERDISC_VIOLENCIAYSOC         29.0         NaN
# 4                  A-  PUNT_INTERDISC_MEDIOAMBIENTE         55.0         NaN
# ...               ...                           ...          ...         ...
# 212005             A2      PUNT_PROFUNDIZA_LENGUAJE          6.0          II
# 212006             B1      PUNT_PROFUNDIZA_BIOLOGIA          5.0           I
# 212007             A-  PUNT_INTERDISC_MEDIOAMBIENTE         52.0         NaN
# 212008             A-  PUNT_INTERDISC_MEDIOAMBIENTE         52.0         NaN
# 212009             A1    PUNT_PROFUNDIZA_MATEMATICA          6.0          II
#
# [212010 rows x 143 columns]

# %% [markdown]
# ### Translate values

# %%
# open dictionary with dictionary of values for variables
file = open("../../data/translate_cat.txt", "r", encoding="utf8")
contents = file.read()
my_dics = ast.literal_eval(contents)
file.close()

# select cathegorical columns
cat_col=df.select_dtypes(include='object').columns.to_list()

# translates to English the values of the data frame
df_2 = df.copy()
for i in cat_col:
    try:
        df_2.replace({i: my_dics[i]}, inplace=True)
    except:
        next

# %% [markdown]
# ### Translate headers

# %%
# open dictionary of translated headers
file = open("../../data/translate_headers.txt", "r")
contents = file.read()
file.close()

# get headers as dictionary 
my_headers = ast.literal_eval(contents) #capital letters
my_headers_low = ast.literal_eval(contents.lower()) #lower case

# translate header
df_2 = df_2.rename(columns=my_headers_low)

# %%
saber = df_2.copy()

# %%
saber.head()
# Out:
#   your_type_of_document your_nationality your_gender your_birthdate  \
# 0                    TI         COLOMBIA           M     30/07/1996
# 1                    CC         COLOMBIA           M     13/04/1994
# 2                    CC         COLOMBIA           F     08/12/1991
# 3                    TI         COLOMBIA           F     10/01/1996
# 4                    CC         COLOMBIA           M     11/10/1995
#
#   your_exterior  period your_consecutive your_marital_status your_student  \
# 0           NaN   20134   EK201340233804              Single      STUDENT
# 1           NaN   20133   EK201330220754              Single      STUDENT
# 2           NaN   20134   EK201340246502              Single      STUDENT
# 3           NaN   20134   EK201340237996              Single      STUDENT
# 4            NO   20173   EK201730119521                 NaN      STUDENT
#
#   your_country_resides  ... score_biology score_chemistry  score_physical  \
# 0             COLOMBIA  ...          39.0            42.0            33.0
# 1             COLOMBIA  ...          52.0            52.0            54.0
# 2             COLOMBIA  ...          50.0            51.0            28.0
# 3             COLOMBIA  ...          34.0            35.0            45.0
# 4             COLOMBIA  ...          57.0            65.0            44.0
#
#   score_social_science  score_philosophy score_english  performance_english  \
# 0                 33.0              29.0          38.0                   A-
# 1                 44.0              47.0          51.0                   A1
# 2                 46.0              45.0          43.0                   A-
# 3                 42.0              40.0          43.0                   A-
# 4                 49.0              43.0          42.0                   A-
#
#                             go_deep score_prof performance_prof
# 0       SCORE_INTERDISC_ENVIRONMENT       49.0              NaN
# 1             SCORE_DEEPEN_LANGUAGE        6.0               II
# 2              SCORE_DEEPEN_BIOLOGY        5.0                I
# 3  SCORE_INTERDISC_VIOLENCE_AND_SOC       29.0              NaN
# 4       SCORE_INTERDISC_ENVIRONMENT       55.0              NaN
#
# [5 rows x 143 columns]

# %%
# Remove duplicated columns

saber = saber.loc[:, ~saber.columns.duplicated()]

# %%
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 150)

# %%
saber.head()
# Out:
#   your_type_of_document your_nationality your_gender your_birthdate  \
# 0                    TI         COLOMBIA           M     30/07/1996
# 1                    CC         COLOMBIA           M     13/04/1994
# 2                    CC         COLOMBIA           F     08/12/1991
# 3                    TI         COLOMBIA           F     10/01/1996
# 4                    CC         COLOMBIA           M     11/10/1995
#
#   your_exterior  period your_consecutive your_marital_status your_student  \
# 0           NaN   20134   EK201340233804              Single      STUDENT
# 1           NaN   20133   EK201330220754              Single      STUDENT
# 2           NaN   20134   EK201340246502              Single      STUDENT
# 3           NaN   20134   EK201340237996              Single      STUDENT
# 4            NO   20173   EK201730119521                 NaN      STUDENT
#
#   your_country_resides your_have_ethnicity your_dept_resides  \
# 0             COLOMBIA                 NaN            BOYACA
# 1             COLOMBIA                 NaN          AMAZONAS
# 2             COLOMBIA                 NaN         RISARALDA
# 3             COLOMBIA                 NaN           BOLIVAR
# 4             COLOMBIA                  No      CUNDINAMARCA
#
#    your_dept_code_resides your_municipality_resides  \
# 0                    15.0                  GUATEQUE
# 1                    91.0                   LETICIA
# 2                    66.0              DOSQUEBRADAS
# 3                    13.0       CARTAGENA DE INDIAS
# 4                    25.0                    SOACHA
#
#    your_municipality_code_resides your_high_school_degree  \
# 0                         15322.0      Technical Bachelor
# 1                         91001.0       Academic Bachelor
# 2                         66170.0      Technical Bachelor
# 3                         13001.0      Technical Bachelor
# 4                         25754.0      Technical Bachelor
#
#    your_year_exam_sb11 your_semester_exam__b11  \
# 0               2013.0            1st semester
# 1               2012.0            2nd semester
# 2               2012.0            2nd semester
# 3               2012.0            2nd semester
# 4                  NaN                     NaN
#
#    your_percentage_credits_approved  \
# 0  Doesn't follow the credit system
# 1                     Less than 75%
# 2  Doesn't follow the credit system
# 3  Doesn't follow the credit system
# 4                               NaN
#
#                   your_tuition_cost_university your_tuition_pymt_scholarship  \
# 0                          Did not pay tuition                           NaN
# 1                          Did not pay tuition                           NaN
# 2                          Did not pay tuition                           NaN
# 3                          Did not pay tuition                           NaN
# 4  Between 2.5 million and less than 4 million                            No
#
#   your_tuition_pymt_credit your_tuition_pymt_parents  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                       Si                        No
#
#   your_tuition_pymt_yourself your_i_take_course_preparation  \
# 0                        NaN                            NaN
# 1                        NaN                             Si
# 2                        NaN                             No
# 3                        NaN                             No
# 4                         No                            NaN
#
#     your_course_teacher_ies your_course_external_support_ies  \
# 0                       NaN                              NaN
# 1   Between 20 and 30 hours          Between 20 and 30 hours
# 2  He did not take a course         He did not take a course
# 3  He did not take a course         He did not take a course
# 4                       NaN                              NaN
#
#   your_course_external_ies your_simulation_type_icfes  \
# 0                      NaN                        NaN
# 1            No tomó curso                         Si
# 2            No tomó curso                         No
# 3            No tomó curso                         No
# 4                      NaN                        NaN
#
#   your_activity_strengths_areas your_activity_strengths_generic  \
# 0                           NaN                             NaN
# 1                            Si                              Si
# 2                            No                              No
# 3                            No                              No
# 4                           NaN                             NaN
#
#    your_on_semester  fami_current_household_type fami_is_the_head_family  \
# 0               2.0  It is habitual or permanent                      No
# 1               2.0  It is habitual or permanent                      No
# 2               2.0  It is habitual or permanent                      No
# 3               5.0  It is habitual or permanent                      No
# 4               8.0  It is habitual or permanent                      No
#
#   fami_econ_dependents          fami_father_education  \
# 0                 None  Undergraduate Degree complete
# 1                 None         Middle School complete
# 2                 None   Elementary school incomplete
# 3                 None      Technical School complete
# 4                 None     Elementary school complete
#
#           fami_mother_education                       fami_father_occupation  \
# 0        Middle School complete                    Profesional independiente
# 1     Technical School complete  Empleado de nivel auxiliar o administrativo
# 2  Elementary school incomplete                 Other activity or occupation
# 3        Middle School complete                 Other activity or occupation
# 4        Middle School complete                               Does not apply
#
#                         fami_mother_occupation fami_father_work  \
# 0                    Profesional independiente              NaN
# 1                                Self-employed              NaN
# 2                                         Home              NaN
# 3  Empleado de nivel auxiliar o administrativo              NaN
# 4                               Does not apply              NaN
#
#   fami_mother_work fami_housing_stratum fami_social_stratum_sisben_y  \
# 0              NaN            Stratum 3     Not classified by SISBEN
# 1              NaN            Stratum 2     Not classified by SISBEN
# 2              NaN            Stratum 2                      Level 2
# 3              NaN            Stratum 1                      Level 1
# 4              NaN            Stratum 3                          NaN
#
#   fami_internet fami_computer fami_have_oven fami_automobile fami_fridge  \
# 0            Si            No             Si              No          Si
# 1            No            Si             Si              Si          Si
# 2            No            No             No              No          Si
# 3            No            No             No              No          No
# 4            Si            Si            NaN              No         NaN
#
#   fami_mobile   fami_num_books fami_landline_phone  \
# 0          Si              NaN                  No
# 1          Si              NaN                  No
# 2          Si              NaN                  No
# 3          Si              NaN                  Si
# 4         NaN  26 TO 100 BOOKS                 NaN
#
#        fami_monthly_family_income your_works_currently  inst_institution_code  \
# 0  Between 3 and less than 5 SMLV                   No                   9110
# 1  Between 2 and less than 3 SMLV                   No                   2106
# 2                Less than 1 SMLV                   No                   9110
# 3                Less than 1 SMLV                   No                   9110
# 4                             NaN                  NaN                   2728
#
#                                inst_institution_name  \
# 0              SERVICIO NACIONAL DE APRENDIZAJE-SENA
# 1         DIRECCION NACIONAL DE ESCUELAS-BOGOTÁ D.C.
# 2              SERVICIO NACIONAL DE APRENDIZAJE-SENA
# 3              SERVICIO NACIONAL DE APRENDIZAJE-SENA
# 4  FUNDACION UNIVERSITARIA DEL AREA ANDINA-BOGOTÁ...
#
#                            your_prgm_academic  your_prgm_academic_snies  \
# 0       TECNOLOGÍA EN CONTABILIDAD Y FINANZAS                   91157.0
# 1  TECNICO PROFESIONAL EN SERVICIO DE POLICIA                   11675.0
# 2       TECNOLOGÍA EN CONTABILIDAD Y FINANZAS                   91157.0
# 3             TECNOLOGIA EN GESTION PORTUARIA                   91227.0
# 4                    NEGOCIOS INTERNACIONALES                    4678.0
#
#                            group_reference  your_prgm_municipality_code  \
# 0  TECNOLOGICO EN ADMINISTRACIÓN Y TURISMO                        11001
# 1        TECNOLOGICO EN MILITAR Y POLICIAL                        11001
# 2  TECNOLOGICO EN ADMINISTRACIÓN Y TURISMO                        66001
# 3  TECNOLOGICO EN ADMINISTRACIÓN Y TURISMO                        13001
# 4                  ADMINISTRACIÓN Y AFINES                        11001
#
#   your_prgm_municipality your_prgm_department your_prgm_academic_level  \
# 0            BOGOTÁ D.C.               BOGOTA               TECHNOLOGY
# 1            BOGOTÁ D.C.               BOGOTA  PROFESSIONAL TECHNICIAN
# 2                PEREIRA            RISARALDA               TECHNOLOGY
# 3    CARTAGENA DE INDIAS              BOLIVAR               TECHNOLOGY
# 4           BOGOTÁ, D.C.               BOGOTA               UNIVERSITY
#
#   your_prgm_method      your_undergraduate_core  your_inst_municipality_code  \
# 0         DISTANCE            PUBLIC ACCOUNTING                        11001
# 1        IN PERSON  MILITARY OR POLICE TRAINING                        11001
# 2         DISTANCE            PUBLIC ACCOUNTING                        11001
# 3         DISTANCE                      ECONOMY                        11001
# 4        IN PERSON               ADMINISTRATION                        11001
#
#   your_inst_municipality your_inst_department    inst_character_academic  \
# 0            BOGOTÁ D.C.               BOGOTA  TECHNOLOGICAL INSTITUTION
# 1            BOGOTÁ D.C.               BOGOTA     UNIVERSITY INSTITUTION
# 2            BOGOTÁ D.C.               BOGOTA  TECHNOLOGICAL INSTITUTION
# 3            BOGOTÁ D.C.               BOGOTA  TECHNOLOGICAL INSTITUTION
# 4           BOGOTÁ, D.C.               BOGOTA     UNIVERSITY INSTITUTION
#
#                  inst_origin  mod_reason_quantitat_point  \
# 0    OFFICIAL NATIONAL LEVEL                         9.6
# 1    OFFICIAL NATIONAL LEVEL                        10.8
# 2    OFFICIAL NATIONAL LEVEL                        10.6
# 3    OFFICIAL NATIONAL LEVEL                         9.3
# 4  NOT OFFICIAL - FOUNDATION                       145.0
#
#    mod_reading_review_point  mod_compete_citizen_point  mod_english_point  \
# 0                       8.3                        8.2                9.4
# 1                      10.1                       11.4                9.6
# 2                      11.2                       10.4                9.5
# 3                       8.2                        9.2                9.5
# 4                     179.0                      118.0              132.0
#
#    mod_communi_written_point your_state_research  your_inst_department_code  \
# 0                        9.4             TO POST                         11
# 1                       10.4             TO POST                         11
# 2                        9.9             TO POST                         11
# 3                        9.4             TO POST                         11
# 4                      138.0             TO POST                         11
#
#   your_type_of_document.1 your_nationality.1 your_gender.1 your_birthdate.1  \
# 0                      TI           COLOMBIA             M       30/07/1996
# 1                      CC           COLOMBIA             M       13/04/1994
# 2                      CC           COLOMBIA             F       08/12/1991
# 3                      TI           COLOMBIA             F       10/01/1996
# 4                      TI           COLOMBIA             M       11/10/1995
#
#    period.1 your_consecutive.1 your_student.1 your_country_resides.1  \
# 0     20122   SB11201220401680        STUDENT               COLOMBIA
# 1     20122   SB11201220585536        STUDENT               COLOMBIA
# 2     20122   SB11201220051348        STUDENT               COLOMBIA
# 3     20122   SB11201220372144        STUDENT               COLOMBIA
# 4     20132   SB11201320427497        STUDENT               COLOMBIA
#
#   your_dept_resides.1  your_dept_code_resides.1 your_municipality_resides.1  \
# 0              BOYACA                      15.0                    GUATEQUE
# 1            AMAZONAS                      91.0                     LETICIA
# 2           RISARALDA                      66.0                     PEREIRA
# 3             BOLIVAR                      13.0         CARTAGENA DE INDIAS
# 4        CUNDINAMARCA                      25.0                      SOACHA
#
#    your_municipality_code_resides.1     your_area_residse  \
# 0                           15322.0  Head of Municipality
# 1                           91001.0  Head of Municipality
# 2                           66001.0  Head of Municipality
# 3                           13001.0  Head of Municipality
# 4                           25754.0  Head of Municipality
#
#            your_tuition your_times_took_exam        fami_father_education.1  \
# 0  Does not pay Pension                  NaN                Graduate Degree
# 1  Does not pay Pension                  NaN         Middle School complete
# 2  Does not pay Pension                  NaN         Middle School complete
# 3  Does not pay Pension                  NaN  Undergraduate Degree complete
# 4  Does not pay Pension                Never         Middle School complete
#
#       fami_mother_education.1  \
# 0      Middle School complete
# 1      Middle School complete
# 2  Elementary school complete
# 3      Middle School complete
# 4  Elementary school complete
#
#                             fami_father_occupation.1  \
# 0                                        Businessman
# 1  Empleado con cargo como director o gerente gen...
# 2                                               Home
# 3      Employee with technical level or professional
# 4                       Other activity or occupation
#
#        fami_mother_occupation.1 fami_housing_stratum.1  \
# 0                   Businessman              Stratum 3
# 1                 Self-employed              Stratum 2
# 2                          Home              Stratum 2
# 3             Operator employee                    NaN
# 4  Other activity or occupation              Stratum 3
#
#   fami_social_stratum_sisben fami_house_members fami_house_rooms  \
# 0   Not classified by SISBEN               Four             Four
# 1   Not classified by SISBEN               Five            Three
# 2                    Level 2               Five            Three
# 3                    Level 1               Nine             Four
# 4   Not classified by SISBEN                Six             Four
#
#                               fami_house_floor fami_internet.1  \
# 0  Polished wood, tile, tablet, marble, carpet              Si
# 1                        Cement, gravel, brick              No
# 2                        Cement, gravel, brick              Si
# 3  Polished wood, tile, tablet, marble, carpet              No
# 4  Polished wood, tile, tablet, marble, carpet              Si
#
#   fami_computer.1 fami_washer fami_microwave fami_oven fami_automobile.1  \
# 0              Si          Si             Si        Si                Si
# 1              No          Si             No        No                No
# 2              Si          Si             Si        Si                No
# 3              No          No             No        No                No
# 4              Si          Si             Si        No                Si
#
#   fami_dvd fami_fridge.1 fami_mobile.1 fami_landline_phone.1  \
# 0       Si            Si            Si                    Si
# 1       Si            No            Si                    Si
# 2       Si            Si            Si                    Si
# 3       Si            No            Si                    No
# 4       Si            Si            Si                    Si
#
#            your_currently_working your_background your_expectations  \
# 0                              No              No               NaN
# 1  Yes, 20 hours or more per week              No               NaN
# 2                              No              Si               NaN
# 3                              No              No               NaN
# 4                              No              No                Si
#
#    cole_code_icfes  cole_dane_code_establishment  \
# 0           5207.0                  1.153220e+11
# 1          38919.0                  1.910010e+11
# 2          61424.0                  1.660010e+11
# 3           9110.0                  1.130010e+11
# 4         157636.0                  3.257540e+11
#
#                       cole_name_establishment cole_type   cole_nature  \
# 0                         I.E. VALLE DE TENZA     MIXED      OFFICIAL
# 1              I.E. INEM JOSE EUSTASIO RIVERA     MIXED      OFFICIAL
# 2                          IE AQUILINO BEDOYA     MIXED      OFFICIAL
# 3  INSTITUCION EDUCATIVA OLGA GONZALEZ ARRAUT     MIXED      OFFICIAL
# 4              LICEO NUESTRA SENORA MILAGROSA     MIXED  NOT OFFICIAL
#
#   cole_calendar cole_bilingual      cole_character  cole_dane_code_campus  \
# 0             A              N  TECHNICAL/ACADEMIC           1.153220e+11
# 1             A              N  TECHNICAL/ACADEMIC           1.910010e+11
# 2             A              N  TECHNICAL/ACADEMIC           1.660010e+11
# 3             A              N  TECHNICAL/ACADEMIC           1.130010e+11
# 4             A            NaN            ACADEMIC           3.257540e+11
#
#                                   cole_name_campus cole_main_campus  \
# 0             I.E. VALLE DE TENZA - SEDE PRINCIPAL              YES
# 1  I.E. INEM JOSE EUSTASIO RIVERA - SEDE PRINCIPAL              YES
# 2                         LIC CIAL AQUILINO BEDOYA              YES
# 3       INSTITUCION EDUCATIVA OLGA GONZALEZ ARRAUT              YES
# 4                   LICEO NUESTRA SENORA MILAGROSA              YES
#
#   cole_area_location cole_journey  cole_municipality_code_location  \
# 0              URBAN      MORNING                          15322.0
# 1              URBAN      MORNING                          91001.0
# 2              URBAN         LATE                          66001.0
# 3              URBAN         LATE                          13001.0
# 4              URBAN     COMPLETE                          25754.0
#
#   cole_municipality_location  cole_dept_code_location cole_dept_location  \
# 0                   GUATEQUE                     15.0             BOYACA
# 1                    LETICIA                     91.0           AMAZONAS
# 2                    PEREIRA                     66.0          RISARALDA
# 3        CARTAGENA DE INDIAS                     13.0            BOLIVAR
# 4                     SOACHA                     25.0       CUNDINAMARCA
#
#    score_language  score_mathematics  score_biology  score_chemistry  \
# 0            32.0               43.0           39.0             42.0
# 1            48.0               64.0           52.0             52.0
# 2            57.0               42.0           50.0             51.0
# 3            40.0               46.0           34.0             35.0
# 4            48.0               44.0           57.0             65.0
#
#    score_physical  score_social_science  score_philosophy  score_english  \
# 0            33.0                  33.0              29.0           38.0
# 1            54.0                  44.0              47.0           51.0
# 2            28.0                  46.0              45.0           43.0
# 3            45.0                  42.0              40.0           43.0
# 4            44.0                  49.0              43.0           42.0
#
#   performance_english                           go_deep  score_prof  \
# 0                  A-       SCORE_INTERDISC_ENVIRONMENT        49.0
# 1                  A1             SCORE_DEEPEN_LANGUAGE         6.0
# 2                  A-              SCORE_DEEPEN_BIOLOGY         5.0
# 3                  A-  SCORE_INTERDISC_VIOLENCE_AND_SOC        29.0
# 4                  A-       SCORE_INTERDISC_ENVIRONMENT        55.0
#
#   performance_prof
# 0              NaN
# 1               II
# 2                I
# 3              NaN
# 4              NaN

# %%
saber.describe()
# Out:
#               period  your_dept_code_resides  your_municipality_code_resides  \
# count  212010.000000           211645.000000                   211645.000000
# mean    20170.184156               37.972761                    29130.862539
# std        14.162938              947.511332                    25780.276662
# min     20123.000000                5.000000                     5001.000000
# 25%     20163.000000               11.000000                    11001.000000
# 50%     20173.000000               13.000000                    13001.000000
# 75%     20183.000000               52.000000                    52001.000000
# max     20184.000000            99999.000000                    99999.000000
#
#        your_year_exam_sb11  your_on_semester  inst_institution_code  \
# count         46960.000000      126187.00000          212010.000000
# mean           2011.922466           6.94940            3476.782727
# std               2.210888           2.68588            3810.251141
# min            1968.000000           1.00000            1101.000000
# 25%            2012.000000           4.00000            1704.000000
# 50%            2012.000000           8.00000            1818.000000
# 75%            2012.000000           9.00000            2849.000000
# max            2015.000000          11.00000          129593.000000
#
#        your_prgm_academic_snies  your_prgm_municipality_code  \
# count             205479.000000                212010.000000
# mean               37047.804530                 27598.687312
# std                39054.944918                 25442.052235
# min                    1.000000                  5001.000000
# 25%                 2524.000000                 11001.000000
# 50%                13734.000000                 11001.000000
# 75%                90876.000000                 52001.000000
# max               106552.000000                 99001.000000
#
#        your_inst_municipality_code  mod_reason_quantitat_point  \
# count                212010.000000               212010.000000
# mean                  23531.839177                  124.132469
# std                   23418.009068                   67.003673
# min                    5001.000000                    0.000000
# 25%                   11001.000000                  100.000000
# 50%                   11001.000000                  145.000000
# 75%                   25175.000000                  172.000000
# max                   99001.000000                  300.000000
#
#        mod_reading_review_point  mod_compete_citizen_point  mod_english_point  \
# count             212010.000000              212010.000000      212010.000000
# mean                 125.597165                 118.642899         128.173597
# std                   67.785399                  65.291892          69.784358
# min                    0.000000                   0.000000           0.000000
# 25%                  101.000000                  88.000000         109.000000
# 50%                  147.000000                 138.000000         147.000000
# 75%                  175.000000                 168.000000         179.000000
# max                  300.000000                 300.000000         300.000000
#
#        mod_communi_written_point  your_inst_department_code       period.1  \
# count              206081.000000              212010.000000  212010.000000
# mean                  122.054210                  23.502028   20125.858903
# std                    67.177796                  23.398977       5.155925
# min                     6.600000                   5.000000   20121.000000
# 25%                    98.000000                  11.000000   20122.000000
# 50%                   141.000000                  11.000000   20122.000000
# 75%                   168.000000                  25.000000   20132.000000
# max                   300.000000                  99.000000   20141.000000
#
#        your_dept_code_resides.1  your_municipality_code_resides.1  \
# count             207003.000000                     207003.000000
# mean                  31.055593                      31219.959063
# std                   26.256827                      26286.061165
# min                    5.000000                       5001.000000
# 25%                   11.000000                      11001.000000
# 50%                   17.000000                      17013.000000
# 75%                   54.000000                      54001.000000
# max                   99.000000                      99773.000000
#
#        cole_code_icfes  cole_dane_code_establishment  cole_dane_code_campus  \
# count    201007.000000                  2.119420e+05           2.120060e+05
# mean      57303.614804                  2.278883e+11           2.280815e+11
# std       47104.013480                  1.016193e+11           1.019350e+11
# min           0.000000                  3.110010e+10           0.000000e+00
# 25%       16691.000000                  1.231820e+11           1.231715e+11
# 50%       42218.000000                  1.865680e+11           1.880010e+11
# 75%       97444.000000                  3.117690e+11           3.117690e+11
# max      179358.000000                  8.548740e+11           8.548740e+11
#
#        cole_municipality_code_location  cole_dept_code_location  \
# count                    212010.000000            212010.000000
# mean                      31352.437918                31.179492
# std                       26240.501407                26.212527
# min                        5001.000000                 5.000000
# 25%                       11001.000000                11.000000
# 50%                       17873.000000                17.000000
# 75%                       54001.000000                54.000000
# max                       99773.000000                99.000000
#
#        score_language  score_mathematics  score_biology  score_chemistry  \
# count   212010.000000      212010.000000  212010.000000    212010.000000
# mean        51.457111          51.778789      49.445092        50.275350
# std          7.551992          12.476416       8.194308         8.353876
# min          0.000000           0.000000      -1.000000         0.000000
# 25%         46.000000          43.000000      44.000000        45.000000
# 50%         52.000000          51.000000      49.000000        50.000000
# 75%         56.000000          58.000000      54.000000        55.000000
# max        109.000000         127.000000     100.000000        95.000000
#
#        score_physical  score_social_science  score_philosophy  score_english  \
# count   212010.000000         212010.000000     212010.000000  212010.000000
# mean        48.835602             49.687142         45.089265      51.896175
# std         10.001497              8.703722          9.299312      14.487412
# min          0.000000              0.000000          0.000000      -1.000000
# 25%         43.000000             44.000000         39.000000      43.000000
# 50%         48.000000             49.000000         45.000000      47.000000
# 75%         55.000000             55.000000         51.000000      58.000000
# max        124.000000            111.000000        103.000000     100.000000
#
#           score_prof
# count  212010.000000
# mean       29.798788
# std        23.229438
# min         0.000000
# 25%         5.000000
# 50%        40.000000
# 75%        52.000000
# max        90.000000

# %%
saber.shape
# Out:
# (212010, 142)

# %%
saber.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212010 entries, 0 to 212009
# Data columns (total 142 columns):
#  #    Column                            Non-Null Count   Dtype
# ---   ------                            --------------   -----
#  0    your_type_of_document             212010 non-null  object
#  1    your_nationality                  212010 non-null  object
#  2    your_gender                       212007 non-null  object
#  3    your_birthdate                    211889 non-null  object
#  4    your_exterior                     164892 non-null  object
#  5    period                            212010 non-null  int64
#  6    your_consecutive                  212010 non-null  object
#  7    your_marital_status               146178 non-null  object
#  8    your_student                      212010 non-null  object
#  9    your_country_resides              212010 non-null  object
#  10   your_have_ethnicity               164578 non-null  object
#  11   your_dept_resides                 211645 non-null  object
#  12   your_dept_code_resides            211645 non-null  float64
#  13   your_municipality_resides         211645 non-null  object
#  14   your_municipality_code_resides    211645 non-null  float64
#  15   your_high_school_degree           210134 non-null  object
#  16   your_year_exam_sb11               46960 non-null   float64
#  17   your_semester_exam__b11           47064 non-null   object
#  18   your_percentage_credits_approved  45022 non-null   object
#  19   your_tuition_cost_university      207965 non-null  object
#  20   your_tuition_pymt_scholarship     166130 non-null  object
#  21   your_tuition_pymt_credit          166566 non-null  object
#  22   your_tuition_pymt_parents         169880 non-null  object
#  23   your_tuition_pymt_yourself        166209 non-null  object
#  24   your_i_take_course_preparation    45732 non-null   object
#  25   your_course_teacher_ies           62556 non-null   object
#  26   your_course_external_support_ies  62598 non-null   object
#  27   your_course_external_ies          62159 non-null   object
#  28   your_simulation_type_icfes        62633 non-null   object
#  29   your_activity_strengths_areas     62632 non-null   object
#  30   your_activity_strengths_generic   62630 non-null   object
#  31   your_on_semester                  126187 non-null  float64
#  32   fami_current_household_type       210297 non-null  object
#  33   fami_is_the_head_family           210299 non-null  object
#  34   fami_econ_dependents              210297 non-null  object
#  35   fami_father_education             206763 non-null  object
#  36   fami_mother_education             206571 non-null  object
#  37   fami_father_occupation            128306 non-null  object
#  38   fami_mother_occupation            128556 non-null  object
#  39   fami_father_work                  77265 non-null   object
#  40   fami_mother_work                  77402 non-null   object
#  41   fami_housing_stratum              206192 non-null  object
#  42   fami_social_stratum_sisben_y      46811 non-null   object
#  43   fami_internet                     206850 non-null  object
#  44   fami_computer                     206341 non-null  object
#  45   fami_have_oven                    46811 non-null   object
#  46   fami_automobile                   206654 non-null  object
#  47   fami_fridge                       47068 non-null   object
#  48   fami_mobile                       47068 non-null   object
#  49   fami_num_books                    163231 non-null  object
#  50   fami_landline_phone               46811 non-null   object
#  51   fami_monthly_family_income        46811 non-null   object
#  52   your_works_currently              46431 non-null   object
#  53   inst_institution_code             212010 non-null  int64
#  54   inst_institution_name             212010 non-null  object
#  55   your_prgm_academic                212010 non-null  object
#  56   your_prgm_academic_snies          205479 non-null  float64
#  57   group_reference                   212010 non-null  object
#  58   your_prgm_municipality_code       212010 non-null  int64
#  59   your_prgm_municipality            212010 non-null  object
#  60   your_prgm_department              212010 non-null  object
#  61   your_prgm_academic_level          212010 non-null  object
#  62   your_prgm_method                  212010 non-null  object
#  63   your_undergraduate_core           211487 non-null  object
#  64   your_inst_municipality_code       212010 non-null  int64
#  65   your_inst_municipality            212010 non-null  object
#  66   your_inst_department              212010 non-null  object
#  67   inst_character_academic           212010 non-null  object
#  68   inst_origin                       212010 non-null  object
#  69   mod_reason_quantitat_point        212010 non-null  float64
#  70   mod_reading_review_point          212010 non-null  float64
#  71   mod_compete_citizen_point         212010 non-null  float64
#  72   mod_english_point                 212010 non-null  float64
#  73   mod_communi_written_point         206081 non-null  float64
#  74   your_state_research               212010 non-null  object
#  75   your_inst_department_code         212010 non-null  int64
#  76   your_type_of_document.1           212010 non-null  object
#  77   your_nationality.1                212010 non-null  object
#  78   your_gender.1                     212000 non-null  object
#  79   your_birthdate.1                  212010 non-null  object
#  80   period.1                          212010 non-null  int64
#  81   your_consecutive.1                212010 non-null  object
#  82   your_student.1                    212010 non-null  object
#  83   your_country_resides.1            212010 non-null  object
#  84   your_dept_resides.1               207003 non-null  object
#  85   your_dept_code_resides.1          207003 non-null  float64
#  86   your_municipality_resides.1       207003 non-null  object
#  87   your_municipality_code_resides.1  207003 non-null  float64
#  88   your_area_residse                 198724 non-null  object
#  89   your_tuition                      210277 non-null  object
#  90   your_times_took_exam              88905 non-null   object
#  91   fami_father_education.1           205192 non-null  object
#  92   fami_mother_education.1           205188 non-null  object
#  93   fami_father_occupation.1          203515 non-null  object
#  94   fami_mother_occupation.1          206363 non-null  object
#  95   fami_housing_stratum.1            204211 non-null  object
#  96   fami_social_stratum_sisben        210149 non-null  object
#  97   fami_house_members                210147 non-null  object
#  98   fami_house_rooms                  210155 non-null  object
#  99   fami_house_floor                  210148 non-null  object
#  100  fami_internet.1                   210144 non-null  object
#  101  fami_computer.1                   204595 non-null  object
#  102  fami_washer                       210148 non-null  object
#  103  fami_microwave                    210148 non-null  object
#  104  fami_oven                         201644 non-null  object
#  105  fami_automobile.1                 210147 non-null  object
#  106  fami_dvd                          210148 non-null  object
#  107  fami_fridge.1                     210155 non-null  object
#  108  fami_mobile.1                     210155 non-null  object
#  109  fami_landline_phone.1             210148 non-null  object
#  110  your_currently_working            208554 non-null  object
#  111  your_background                   212010 non-null  object
#  112  your_expectations                 80334 non-null   object
#  113  cole_code_icfes                   201007 non-null  float64
#  114  cole_dane_code_establishment      211942 non-null  float64
#  115  cole_name_establishment           212010 non-null  object
#  116  cole_type                         212010 non-null  object
#  117  cole_nature                       212010 non-null  object
#  118  cole_calendar                     211990 non-null  object
#  119  cole_bilingual                    196459 non-null  object
#  120  cole_character                    211683 non-null  object
#  121  cole_dane_code_campus             212006 non-null  float64
#  122  cole_name_campus                  212010 non-null  object
#  123  cole_main_campus                  212010 non-null  object
#  124  cole_area_location                211950 non-null  object
#  125  cole_journey                      212010 non-null  object
#  126  cole_municipality_code_location   212010 non-null  float64
#  127  cole_municipality_location        212010 non-null  object
#  128  cole_dept_code_location           212010 non-null  float64
#  129  cole_dept_location                212010 non-null  object
#  130  score_language                    212010 non-null  float64
#  131  score_mathematics                 212010 non-null  float64
#  132  score_biology                     212010 non-null  float64
#  133  score_chemistry                   212010 non-null  float64
#  134  score_physical                    212010 non-null  float64
#  135  score_social_science              212010 non-null  float64
#  136  score_philosophy                  212010 non-null  float64
#  137  score_english                     212010 non-null  float64
#  138  performance_english               211988 non-null  object
#  139  go_deep                           212010 non-null  object
#  140  score_prof                        212010 non-null  float64
#  141  performance_prof                  97955 non-null   object
# dtypes: float64(26), int64(6), object(110)
# memory usage: 229.7+ MB

# %%
saber.isnull().sum()
# Out:
# your_type_of_document                    0
# your_nationality                         0
# your_gender                              3
# your_birthdate                         121
# your_exterior                        47118
# period                                   0
# your_consecutive                         0
# your_marital_status                  65832
# your_student                             0
# your_country_resides                     0
# your_have_ethnicity                  47432
# your_dept_resides                      365
# your_dept_code_resides                 365
# your_municipality_resides              365
# your_municipality_code_resides         365
# your_high_school_degree               1876
# your_year_exam_sb11                 165050
# your_semester_exam__b11             164946
# your_percentage_credits_approved    166988
# your_tuition_cost_university          4045
# your_tuition_pymt_scholarship        45880
# your_tuition_pymt_credit             45444
# your_tuition_pymt_parents            42130
# your_tuition_pymt_yourself           45801
# your_i_take_course_preparation      166278
# your_course_teacher_ies             149454
# your_course_external_support_ies    149412
# your_course_external_ies            149851
# your_simulation_type_icfes          149377
# your_activity_strengths_areas       149378
# your_activity_strengths_generic     149380
# your_on_semester                     85823
# fami_current_household_type           1713
# fami_is_the_head_family               1711
# fami_econ_dependents                  1713
# fami_father_education                 5247
# fami_mother_education                 5439
# fami_father_occupation               83704
# fami_mother_occupation               83454
# fami_father_work                    134745
# fami_mother_work                    134608
# fami_housing_stratum                  5818
# fami_social_stratum_sisben_y        165199
# fami_internet                         5160
# fami_computer                         5669
# fami_have_oven                      165199
# fami_automobile                       5356
# fami_fridge                         164942
# fami_mobile                         164942
# fami_num_books                       48779
# fami_landline_phone                 165199
# fami_monthly_family_income          165199
# your_works_currently                165579
# inst_institution_code                    0
# inst_institution_name                    0
# your_prgm_academic                       0
# your_prgm_academic_snies              6531
# group_reference                          0
# your_prgm_municipality_code              0
# your_prgm_municipality                   0
# your_prgm_department                     0
# your_prgm_academic_level                 0
# your_prgm_method                         0
# your_undergraduate_core                523
# your_inst_municipality_code              0
# your_inst_municipality                   0
# your_inst_department                     0
# inst_character_academic                  0
# inst_origin                              0
# mod_reason_quantitat_point               0
# mod_reading_review_point                 0
# mod_compete_citizen_point                0
# mod_english_point                        0
# mod_communi_written_point             5929
# your_state_research                      0
# your_inst_department_code                0
# your_type_of_document.1                  0
# your_nationality.1                       0
# your_gender.1                           10
# your_birthdate.1                         0
# period.1                                 0
# your_consecutive.1                       0
# your_student.1                           0
# your_country_resides.1                   0
# your_dept_resides.1                   5007
# your_dept_code_resides.1              5007
# your_municipality_resides.1           5007
# your_municipality_code_resides.1      5007
# your_area_residse                    13286
# your_tuition                          1733
# your_times_took_exam                123105
# fami_father_education.1               6818
# fami_mother_education.1               6822
# fami_father_occupation.1              8495
# fami_mother_occupation.1              5647
# fami_housing_stratum.1                7799
# fami_social_stratum_sisben            1861
# fami_house_members                    1863
# fami_house_rooms                      1855
# fami_house_floor                      1862
# fami_internet.1                       1866
# fami_computer.1                       7415
# fami_washer                           1862
# fami_microwave                        1862
# fami_oven                            10366
# fami_automobile.1                     1863
# fami_dvd                              1862
# fami_fridge.1                         1855
# fami_mobile.1                         1855
# fami_landline_phone.1                 1862
# your_currently_working                3456
# your_background                          0
# your_expectations                   131676
# cole_code_icfes                      11003
# cole_dane_code_establishment            68
# cole_name_establishment                  0
# cole_type                                0
# cole_nature                              0
# cole_calendar                           20
# cole_bilingual                       15551
# cole_character                         327
# cole_dane_code_campus                    4
# cole_name_campus                         0
# cole_main_campus                         0
# cole_area_location                      60
# cole_journey                             0
# cole_municipality_code_location          0
# cole_municipality_location               0
# cole_dept_code_location                  0
# cole_dept_location                       0
# score_language                           0
# score_mathematics                        0
# score_biology                            0
# score_chemistry                          0
# score_physical                           0
# score_social_science                     0
# score_philosophy                         0
# score_english                            0
# performance_english                     22
# go_deep                                  0
# score_prof                               0
# performance_prof                    114055
# dtype: int64

# %% [markdown]
# ## Finding NAN Percentage per Column

# %%
percent_nan = saber.isnull().sum() * 100 / len(saber)
saber_nan_values = pd.DataFrame({'column_name':saber.columns, 
                                 'percent_nan':percent_nan})

saber_nan_values.sort_values('percent_nan', ascending=False, inplace=True)
saber_nan_values[['percent_nan']]
# Out:
#                                   percent_nan
# your_percentage_credits_approved    78.764209
# your_i_take_course_preparation      78.429319
# your_works_currently                78.099618
# fami_monthly_family_income          77.920381
# fami_social_stratum_sisben_y        77.920381
# fami_have_oven                      77.920381
# fami_landline_phone                 77.920381
# your_year_exam_sb11                 77.850101
# your_semester_exam__b11             77.801047
# fami_fridge                         77.799160
# fami_mobile                         77.799160
# your_course_external_ies            70.681100
# your_course_teacher_ies             70.493845
# your_course_external_support_ies    70.474034
# your_activity_strengths_generic     70.458941
# your_activity_strengths_areas       70.457997
# your_simulation_type_icfes          70.457526
# fami_father_work                    63.555964
# fami_mother_work                    63.491345
# your_expectations                   62.108391
# your_times_took_exam                58.065657
# performance_prof                    53.796991
# your_on_semester                    40.480638
# fami_father_occupation              39.481157
# fami_mother_occupation              39.363238
# your_marital_status                 31.051366
# fami_num_books                      23.007877
# your_have_ethnicity                 22.372530
# your_exterior                       22.224423
# your_tuition_pymt_scholarship       21.640489
# your_tuition_pymt_yourself          21.603226
# your_tuition_pymt_credit            21.434838
# your_tuition_pymt_parents           19.871704
# cole_bilingual                       7.335031
# your_area_residse                    6.266686
# cole_code_icfes                      5.189850
# fami_oven                            4.889392
# fami_father_occupation.1             4.006886
# fami_housing_stratum.1               3.678600
# fami_computer.1                      3.497477
# fami_mother_education.1              3.217773
# fami_father_education.1              3.215886
# your_prgm_academic_snies             3.080515
# mod_communi_written_point            2.796566
# fami_housing_stratum                 2.744210
# fami_computer                        2.673930
# fami_mother_occupation.1             2.663554
# fami_mother_education                2.565445
# fami_automobile                      2.526296
# fami_father_education                2.474883
# fami_internet                        2.433847
# your_municipality_resides.1          2.361681
# your_dept_resides.1                  2.361681
# your_dept_code_resides.1             2.361681
# your_municipality_code_resides.1     2.361681
# your_tuition_cost_university         1.907929
# your_currently_working               1.630112
# your_high_school_degree              0.884864
# fami_internet.1                      0.880147
# fami_house_members                   0.878732
# fami_automobile.1                    0.878732
# fami_dvd                             0.878260
# fami_landline_phone.1                0.878260
# fami_microwave                       0.878260
# fami_washer                          0.878260
# fami_house_floor                     0.878260
# fami_social_stratum_sisben           0.877789
# fami_house_rooms                     0.874959
# fami_fridge.1                        0.874959
# fami_mobile.1                        0.874959
# your_tuition                         0.817414
# fami_current_household_type          0.807981
# fami_econ_dependents                 0.807981
# fami_is_the_head_family              0.807037
# your_undergraduate_core              0.246686
# your_dept_resides                    0.172162
# your_dept_code_resides               0.172162
# your_municipality_resides            0.172162
# your_municipality_code_resides       0.172162
# cole_character                       0.154238
# your_birthdate                       0.057073
# cole_dane_code_establishment         0.032074
# cole_area_location                   0.028301
# performance_english                  0.010377
# cole_calendar                        0.009434
# your_gender.1                        0.004717
# cole_dane_code_campus                0.001887
# your_gender                          0.001415
# cole_dept_location                   0.000000
# score_language                       0.000000
# cole_name_campus                     0.000000
# score_prof                           0.000000
# go_deep                              0.000000
# cole_main_campus                     0.000000
# score_english                        0.000000
# cole_nature                          0.000000
# cole_type                            0.000000
# cole_name_establishment              0.000000
# cole_journey                         0.000000
# your_background                      0.000000
# cole_municipality_code_location      0.000000
# cole_municipality_location           0.000000
# score_philosophy                     0.000000
# score_physical                       0.000000
# score_chemistry                      0.000000
# score_biology                        0.000000
# score_mathematics                    0.000000
# cole_dept_code_location              0.000000
# score_social_science                 0.000000
# your_type_of_document                0.000000
# your_country_resides.1               0.000000
# your_student.1                       0.000000
# period                               0.000000
# your_consecutive                     0.000000
# your_student                         0.000000
# your_country_resides                 0.000000
# inst_institution_code                0.000000
# inst_institution_name                0.000000
# your_prgm_academic                   0.000000
# group_reference                      0.000000
# your_prgm_municipality_code          0.000000
# your_prgm_municipality               0.000000
# your_prgm_department                 0.000000
# your_prgm_academic_level             0.000000
# your_prgm_method                     0.000000
# your_inst_municipality_code          0.000000
# your_inst_municipality               0.000000
# your_inst_department                 0.000000
# inst_character_academic              0.000000
# inst_origin                          0.000000
# mod_reason_quantitat_point           0.000000
# mod_reading_review_point             0.000000
# your_nationality                     0.000000
# mod_english_point                    0.000000
# your_state_research                  0.000000
# your_inst_department_code            0.000000
# your_type_of_document.1              0.000000
# your_nationality.1                   0.000000
# your_birthdate.1                     0.000000
# period.1                             0.000000
# your_consecutive.1                   0.000000
# mod_compete_citizen_point            0.000000

# %%
# Credits to Ayoub for the cat and num feature division

# Categorical features
cat_col=saber.select_dtypes(include='object').columns.to_list()
print(cat_col)

# Numerical features
num_col=saber.select_dtypes(include='number').columns.to_list()
print(num_col)
# Out:
# ['your_type_of_document', 'your_nationality', 'your_gender', 'your_birthdate', 'your_exterior', 'your_consecutive', 'your_marital_status', 'your_student', 'your_country_resides', 'your_have_ethnicity', 'your_dept_resides', 'your_municipality_resides', 'your_high_school_degree', 'your_semester_exam__b11', 'your_percentage_credits_approved', 'your_tuition_cost_university', 'your_tuition_pymt_scholarship', 'your_tuition_pymt_credit', 'your_tuition_pymt_parents', 'your_tuition_pymt_yourself', 'your_i_take_course_preparation', 'your_course_teacher_ies', 'your_course_external_support_ies', 'your_course_external_ies', 'your_simulation_type_icfes', 'your_activity_strengths_areas', 'your_activity_strengths_generic', 'fami_current_household_type', 'fami_is_the_head_family', 'fami_econ_dependents', 'fami_father_education', 'fami_mother_education', 'fami_father_occupation', 'fami_mother_occupation', 'fami_father_work', 'fami_mother_work', 'fami_housing_stratum', 'fami_social_stratum_sisben_y', 'fami_internet', 'fami_computer', 'fami_have_oven', 'fami_automobile', 'fami_fridge', 'fami_mobile', 'fami_num_books', 'fami_landline_phone', 'fami_monthly_family_income', 'your_works_currently', 'inst_institution_name', 'your_prgm_academic', 'group_reference', 'your_prgm_municipality', 'your_prgm_department', 'your_prgm_academic_level', 'your_prgm_method', 'your_undergraduate_core', 'your_inst_municipality', 'your_inst_department', 'inst_character_academic', 'inst_origin', 'your_state_research', 'your_type_of_document.1', 'your_nationality.1', 'your_gender.1', 'your_birthdate.1', 'your_consecutive.1', 'your_student.1', 'your_country_resides.1', 'your_dept_resides.1', 'your_municipality_resides.1', 'your_area_residse', 'your_tuition', 'your_times_took_exam', 'fami_father_education.1', 'fami_mother_education.1', 'fami_father_occupation.1', 'fami_mother_occupation.1', 'fami_housing_stratum.1', 'fami_social_stratum_sisben', 'fami_house_members', 'fami_house_rooms', 'fami_house_floor', 'fami_internet.1', 'fami_computer.1', 'fami_washer', 'fami_microwave', 'fami_oven', 'fami_automobile.1', 'fami_dvd', 'fami_fridge.1', 'fami_mobile.1', 'fami_landline_phone.1', 'your_currently_working', 'your_background', 'your_expectations', 'cole_name_establishment', 'cole_type', 'cole_nature', 'cole_calendar', 'cole_bilingual', 'cole_character', 'cole_name_campus', 'cole_main_campus', 'cole_area_location', 'cole_journey', 'cole_municipality_location', 'cole_dept_location', 'performance_english', 'go_deep', 'performance_prof']
# ['period', 'your_dept_code_resides', 'your_municipality_code_resides', 'your_year_exam_sb11', 'your_on_semester', 'inst_institution_code', 'your_prgm_academic_snies', 'your_prgm_municipality_code', 'your_inst_municipality_code', 'mod_reason_quantitat_point', 'mod_reading_review_point', 'mod_compete_citizen_point', 'mod_english_point', 'mod_communi_written_point', 'your_inst_department_code', 'period.1', 'your_dept_code_resides.1', 'your_municipality_code_resides.1', 'cole_code_icfes', 'cole_dane_code_establishment', 'cole_dane_code_campus', 'cole_municipality_code_location', 'cole_dept_code_location', 'score_language', 'score_mathematics', 'score_biology', 'score_chemistry', 'score_physical', 'score_social_science', 'score_philosophy', 'score_english', 'score_prof']

# %%
saber_nan_cat_values = saber_nan_values.loc[cat_col].sort_values('percent_nan', ascending=False)
saber_nan_cat_values.reset_index(drop=True)
# Out:
#                           column_name  percent_nan
# 0    your_percentage_credits_approved    78.764209
# 1      your_i_take_course_preparation    78.429319
# 2                your_works_currently    78.099618
# 3          fami_monthly_family_income    77.920381
# 4                 fami_landline_phone    77.920381
# 5                      fami_have_oven    77.920381
# 6        fami_social_stratum_sisben_y    77.920381
# 7             your_semester_exam__b11    77.801047
# 8                         fami_fridge    77.799160
# 9                         fami_mobile    77.799160
# 10           your_course_external_ies    70.681100
# 11            your_course_teacher_ies    70.493845
# 12   your_course_external_support_ies    70.474034
# 13    your_activity_strengths_generic    70.458941
# 14      your_activity_strengths_areas    70.457997
# 15         your_simulation_type_icfes    70.457526
# 16                   fami_father_work    63.555964
# 17                   fami_mother_work    63.491345
# 18                  your_expectations    62.108391
# 19               your_times_took_exam    58.065657
# 20                   performance_prof    53.796991
# 21             fami_father_occupation    39.481157
# 22             fami_mother_occupation    39.363238
# 23                your_marital_status    31.051366
# 24                     fami_num_books    23.007877
# 25                your_have_ethnicity    22.372530
# 26                      your_exterior    22.224423
# 27      your_tuition_pymt_scholarship    21.640489
# 28         your_tuition_pymt_yourself    21.603226
# 29           your_tuition_pymt_credit    21.434838
# 30          your_tuition_pymt_parents    19.871704
# 31                     cole_bilingual     7.335031
# 32                  your_area_residse     6.266686
# 33                          fami_oven     4.889392
# 34           fami_father_occupation.1     4.006886
# 35             fami_housing_stratum.1     3.678600
# 36                    fami_computer.1     3.497477
# 37            fami_mother_education.1     3.217773
# 38            fami_father_education.1     3.215886
# 39               fami_housing_stratum     2.744210
# 40                      fami_computer     2.673930
# 41           fami_mother_occupation.1     2.663554
# 42              fami_mother_education     2.565445
# 43                    fami_automobile     2.526296
# 44              fami_father_education     2.474883
# 45                      fami_internet     2.433847
# 46                your_dept_resides.1     2.361681
# 47        your_municipality_resides.1     2.361681
# 48       your_tuition_cost_university     1.907929
# 49             your_currently_working     1.630112
# 50            your_high_school_degree     0.884864
# 51                    fami_internet.1     0.880147
# 52                 fami_house_members     0.878732
# 53                  fami_automobile.1     0.878732
# 54                   fami_house_floor     0.878260
# 55                        fami_washer     0.878260
# 56                     fami_microwave     0.878260
# 57              fami_landline_phone.1     0.878260
# 58                           fami_dvd     0.878260
# 59         fami_social_stratum_sisben     0.877789
# 60                   fami_house_rooms     0.874959
# 61                      fami_mobile.1     0.874959
# 62                      fami_fridge.1     0.874959
# 63                       your_tuition     0.817414
# 64        fami_current_household_type     0.807981
# 65               fami_econ_dependents     0.807981
# 66            fami_is_the_head_family     0.807037
# 67            your_undergraduate_core     0.246686
# 68                  your_dept_resides     0.172162
# 69          your_municipality_resides     0.172162
# 70                     cole_character     0.154238
# 71                     your_birthdate     0.057073
# 72                 cole_area_location     0.028301
# 73                performance_english     0.010377
# 74                      cole_calendar     0.009434
# 75                      your_gender.1     0.004717
# 76                        your_gender     0.001415
# 77                   cole_main_campus     0.000000
# 78                   cole_name_campus     0.000000
# 79               your_country_resides     0.000000
# 80                       cole_journey     0.000000
# 81         cole_municipality_location     0.000000
# 82                        cole_nature     0.000000
# 83                          cole_type     0.000000
# 84            cole_name_establishment     0.000000
# 85                 cole_dept_location     0.000000
# 86                    your_background     0.000000
# 87                   your_consecutive     0.000000
# 88                            go_deep     0.000000
# 89                       your_student     0.000000
# 90             your_country_resides.1     0.000000
# 91                     your_student.1     0.000000
# 92               your_inst_department     0.000000
# 93                 your_consecutive.1     0.000000
# 94                   your_birthdate.1     0.000000
# 95                 your_nationality.1     0.000000
# 96            your_type_of_document.1     0.000000
# 97                your_state_research     0.000000
# 98                        inst_origin     0.000000
# 99            inst_character_academic     0.000000
# 100            your_inst_municipality     0.000000
# 101             inst_institution_name     0.000000
# 102                  your_nationality     0.000000
# 103                  your_prgm_method     0.000000
# 104          your_prgm_academic_level     0.000000
# 105              your_prgm_department     0.000000
# 106            your_prgm_municipality     0.000000
# 107                   group_reference     0.000000
# 108                your_prgm_academic     0.000000
# 109             your_type_of_document     0.000000

# %%
saber_nan_num_values = saber_nan_values.loc[num_col].sort_values('percent_nan', ascending=False)
saber_nan_num_values.reset_index(drop=True)
# Out:
#                          column_name  percent_nan
# 0                your_year_exam_sb11    77.850101
# 1                   your_on_semester    40.480638
# 2                    cole_code_icfes     5.189850
# 3           your_prgm_academic_snies     3.080515
# 4          mod_communi_written_point     2.796566
# 5           your_dept_code_resides.1     2.361681
# 6   your_municipality_code_resides.1     2.361681
# 7     your_municipality_code_resides     0.172162
# 8             your_dept_code_resides     0.172162
# 9       cole_dane_code_establishment     0.032074
# 10             cole_dane_code_campus     0.001887
# 11                     score_biology     0.000000
# 12                 score_mathematics     0.000000
# 13   cole_municipality_code_location     0.000000
# 14                    score_language     0.000000
# 15           cole_dept_code_location     0.000000
# 16                    score_physical     0.000000
# 17              score_social_science     0.000000
# 18                  score_philosophy     0.000000
# 19                     score_english     0.000000
# 20                   score_chemistry     0.000000
# 21                            period     0.000000
# 22                          period.1     0.000000
# 23         your_inst_department_code     0.000000
# 24                 mod_english_point     0.000000
# 25         mod_compete_citizen_point     0.000000
# 26          mod_reading_review_point     0.000000
# 27        mod_reason_quantitat_point     0.000000
# 28       your_inst_municipality_code     0.000000
# 29       your_prgm_municipality_code     0.000000
# 30             inst_institution_code     0.000000
# 31                        score_prof     0.000000

# %%
cat_nan_columns = saber_nan_cat_values[saber_nan_cat_values['percent_nan'] > 20]['column_name'].to_list()
num_nan_columns = saber_nan_num_values[saber_nan_num_values['percent_nan'] > 20]['column_name'].to_list()

print("There are {} categorical columns with more than 20% nan values".format(len(cat_nan_columns)))
print("There are {} numerical columns with more than 20% nan values".format(len(num_nan_columns)))
# Out:
# There are 30 categorical columns with more than 20% nan values
# There are 2 numerical columns with more than 20% nan values

# %% [markdown]
# #### Although there are 32 columns with more than 20% NaN values, I'll be performing some data visualizations to determine the relationships between columns and Saber pro. Some of these categorical columns, albeit having majority NaN values, can tell us something about the distribution of student population across Colombia.

# %% [markdown]
# ## Questions for Visualization
#
# Looping here the questions I came up with for the initial visualization. Feel free to chime in, add, remove, and change some questions. Question list should be updated as we go along.
#
# 1. What are the statistics of the scores of colombian students based on:
#     - Ethnicity
#     - State
#     - Municipality
#     - College Degree
#     - Social Classes
#         - Mother's job
#         - Father's job
#         - Mother's Education
#         - Father's Education
#     - Colombian Sisben level
#     - Family necessities
#         - Internet
#         - kiln
#         - car
#         - fridge
#         - cellphone
#         - books
#         - phone
#         - Number of people at home
#         - Number of bedrooms
#         - Number of floors
#     - Mensual Monthly Income
#     - School Type
#     - House Stratum
# 2. Based on the answers from 1, what are the jobs suggested to those who have said statistics?
# 3. What is the relationship between taking a practice test and general preparation to test scores? Does taking these prep increase test scores? <br>
#    3.1 Moreover, what's the social class of those who are able to take these preparation tests? Is there a social divide amongst those who do take and do not?
# 4. Is there a correlation between the current academic program and the results of Saber? Does the academic program really influence the saber results and vice versa?
# 5. Which student group got the highest in the respective ICFES areas? Opposite approach: get the highest and lowest of students and determine their classes from there.
# 6. Why do students get the lowest score? Why do they get the highest scores?

# %%
marks = [
 'score_language',
 'score_mathematics',
 'score_biology',
 'score_chemistry',
 'score_physical',
 'score_social_science',
 'score_philosophy',
 'score_english',
 'score_prof', 
 'mod_reason_quantitat_point',
 'mod_reading_review_point',
 'mod_compete_citizen_point',
 'mod_english_point',
 'mod_communi_written_point'
 ]

saber_marks = [ 
 'score_language',
 'score_mathematics',
 'score_biology',
 'score_chemistry',
 'score_physical',
 'score_social_science',
 'score_philosophy',
 'score_english',
 'score_prof'
 ]

saber_pro_marks = [
 'mod_reason_quantitat_point',
 'mod_reading_review_point',
 'mod_compete_citizen_point',
 'mod_english_point',
 'mod_communi_written_point']

# %%
# Adding column of total saber and saber pro scores

saber['total_saber_score'] = saber[saber_marks].sum(axis=1)
saber['total_saber_pro_score'] = saber[saber_pro_marks].sum(axis=1)

# %%
saber.head()
# Out:
#   your_type_of_document your_nationality your_gender your_birthdate  \
# 0                    TI         COLOMBIA           M     30/07/1996
# 1                    CC         COLOMBIA           M     13/04/1994
# 2                    CC         COLOMBIA           F     08/12/1991
# 3                    TI         COLOMBIA           F     10/01/1996
# 4                    CC         COLOMBIA           M     11/10/1995
#
#   your_exterior  period your_consecutive your_marital_status your_student  \
# 0           NaN   20134   EK201340233804              Single      STUDENT
# 1           NaN   20133   EK201330220754              Single      STUDENT
# 2           NaN   20134   EK201340246502              Single      STUDENT
# 3           NaN   20134   EK201340237996              Single      STUDENT
# 4            NO   20173   EK201730119521                 NaN      STUDENT
#
#   your_country_resides your_have_ethnicity your_dept_resides  \
# 0             COLOMBIA                 NaN            BOYACA
# 1             COLOMBIA                 NaN          AMAZONAS
# 2             COLOMBIA                 NaN         RISARALDA
# 3             COLOMBIA                 NaN           BOLIVAR
# 4             COLOMBIA                  No      CUNDINAMARCA
#
#    your_dept_code_resides your_municipality_resides  \
# 0                    15.0                  GUATEQUE
# 1                    91.0                   LETICIA
# 2                    66.0              DOSQUEBRADAS
# 3                    13.0       CARTAGENA DE INDIAS
# 4                    25.0                    SOACHA
#
#    your_municipality_code_resides your_high_school_degree  \
# 0                         15322.0      Technical Bachelor
# 1                         91001.0       Academic Bachelor
# 2                         66170.0      Technical Bachelor
# 3                         13001.0      Technical Bachelor
# 4                         25754.0      Technical Bachelor
#
#    your_year_exam_sb11 your_semester_exam__b11  \
# 0               2013.0            1st semester
# 1               2012.0            2nd semester
# 2               2012.0            2nd semester
# 3               2012.0            2nd semester
# 4                  NaN                     NaN
#
#    your_percentage_credits_approved  \
# 0  Doesn't follow the credit system
# 1                     Less than 75%
# 2  Doesn't follow the credit system
# 3  Doesn't follow the credit system
# 4                               NaN
#
#                   your_tuition_cost_university your_tuition_pymt_scholarship  \
# 0                          Did not pay tuition                           NaN
# 1                          Did not pay tuition                           NaN
# 2                          Did not pay tuition                           NaN
# 3                          Did not pay tuition                           NaN
# 4  Between 2.5 million and less than 4 million                            No
#
#   your_tuition_pymt_credit your_tuition_pymt_parents  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                       Si                        No
#
#   your_tuition_pymt_yourself your_i_take_course_preparation  \
# 0                        NaN                            NaN
# 1                        NaN                             Si
# 2                        NaN                             No
# 3                        NaN                             No
# 4                         No                            NaN
#
#     your_course_teacher_ies your_course_external_support_ies  \
# 0                       NaN                              NaN
# 1   Between 20 and 30 hours          Between 20 and 30 hours
# 2  He did not take a course         He did not take a course
# 3  He did not take a course         He did not take a course
# 4                       NaN                              NaN
#
#   your_course_external_ies your_simulation_type_icfes  \
# 0                      NaN                        NaN
# 1            No tomó curso                         Si
# 2            No tomó curso                         No
# 3            No tomó curso                         No
# 4                      NaN                        NaN
#
#   your_activity_strengths_areas your_activity_strengths_generic  \
# 0                           NaN                             NaN
# 1                            Si                              Si
# 2                            No                              No
# 3                            No                              No
# 4                           NaN                             NaN
#
#    your_on_semester  fami_current_household_type fami_is_the_head_family  \
# 0               2.0  It is habitual or permanent                      No
# 1               2.0  It is habitual or permanent                      No
# 2               2.0  It is habitual or permanent                      No
# 3               5.0  It is habitual or permanent                      No
# 4               8.0  It is habitual or permanent                      No
#
#   fami_econ_dependents          fami_father_education  \
# 0                 None  Undergraduate Degree complete
# 1                 None         Middle School complete
# 2                 None   Elementary school incomplete
# 3                 None      Technical School complete
# 4                 None     Elementary school complete
#
#           fami_mother_education                       fami_father_occupation  \
# 0        Middle School complete                    Profesional independiente
# 1     Technical School complete  Empleado de nivel auxiliar o administrativo
# 2  Elementary school incomplete                 Other activity or occupation
# 3        Middle School complete                 Other activity or occupation
# 4        Middle School complete                               Does not apply
#
#                         fami_mother_occupation fami_father_work  \
# 0                    Profesional independiente              NaN
# 1                                Self-employed              NaN
# 2                                         Home              NaN
# 3  Empleado de nivel auxiliar o administrativo              NaN
# 4                               Does not apply              NaN
#
#   fami_mother_work fami_housing_stratum fami_social_stratum_sisben_y  \
# 0              NaN            Stratum 3     Not classified by SISBEN
# 1              NaN            Stratum 2     Not classified by SISBEN
# 2              NaN            Stratum 2                      Level 2
# 3              NaN            Stratum 1                      Level 1
# 4              NaN            Stratum 3                          NaN
#
#   fami_internet fami_computer fami_have_oven fami_automobile fami_fridge  \
# 0            Si            No             Si              No          Si
# 1            No            Si             Si              Si          Si
# 2            No            No             No              No          Si
# 3            No            No             No              No          No
# 4            Si            Si            NaN              No         NaN
#
#   fami_mobile   fami_num_books fami_landline_phone  \
# 0          Si              NaN                  No
# 1          Si              NaN                  No
# 2          Si              NaN                  No
# 3          Si              NaN                  Si
# 4         NaN  26 TO 100 BOOKS                 NaN
#
#        fami_monthly_family_income your_works_currently  inst_institution_code  \
# 0  Between 3 and less than 5 SMLV                   No                   9110
# 1  Between 2 and less than 3 SMLV                   No                   2106
# 2                Less than 1 SMLV                   No                   9110
# 3                Less than 1 SMLV                   No                   9110
# 4                             NaN                  NaN                   2728
#
#                                inst_institution_name  \
# 0              SERVICIO NACIONAL DE APRENDIZAJE-SENA
# 1         DIRECCION NACIONAL DE ESCUELAS-BOGOTÁ D.C.
# 2              SERVICIO NACIONAL DE APRENDIZAJE-SENA
# 3              SERVICIO NACIONAL DE APRENDIZAJE-SENA
# 4  FUNDACION UNIVERSITARIA DEL AREA ANDINA-BOGOTÁ...
#
#                            your_prgm_academic  your_prgm_academic_snies  \
# 0       TECNOLOGÍA EN CONTABILIDAD Y FINANZAS                   91157.0
# 1  TECNICO PROFESIONAL EN SERVICIO DE POLICIA                   11675.0
# 2       TECNOLOGÍA EN CONTABILIDAD Y FINANZAS                   91157.0
# 3             TECNOLOGIA EN GESTION PORTUARIA                   91227.0
# 4                    NEGOCIOS INTERNACIONALES                    4678.0
#
#                            group_reference  your_prgm_municipality_code  \
# 0  TECNOLOGICO EN ADMINISTRACIÓN Y TURISMO                        11001
# 1        TECNOLOGICO EN MILITAR Y POLICIAL                        11001
# 2  TECNOLOGICO EN ADMINISTRACIÓN Y TURISMO                        66001
# 3  TECNOLOGICO EN ADMINISTRACIÓN Y TURISMO                        13001
# 4                  ADMINISTRACIÓN Y AFINES                        11001
#
#   your_prgm_municipality your_prgm_department your_prgm_academic_level  \
# 0            BOGOTÁ D.C.               BOGOTA               TECHNOLOGY
# 1            BOGOTÁ D.C.               BOGOTA  PROFESSIONAL TECHNICIAN
# 2                PEREIRA            RISARALDA               TECHNOLOGY
# 3    CARTAGENA DE INDIAS              BOLIVAR               TECHNOLOGY
# 4           BOGOTÁ, D.C.               BOGOTA               UNIVERSITY
#
#   your_prgm_method      your_undergraduate_core  your_inst_municipality_code  \
# 0         DISTANCE            PUBLIC ACCOUNTING                        11001
# 1        IN PERSON  MILITARY OR POLICE TRAINING                        11001
# 2         DISTANCE            PUBLIC ACCOUNTING                        11001
# 3         DISTANCE                      ECONOMY                        11001
# 4        IN PERSON               ADMINISTRATION                        11001
#
#   your_inst_municipality your_inst_department    inst_character_academic  \
# 0            BOGOTÁ D.C.               BOGOTA  TECHNOLOGICAL INSTITUTION
# 1            BOGOTÁ D.C.               BOGOTA     UNIVERSITY INSTITUTION
# 2            BOGOTÁ D.C.               BOGOTA  TECHNOLOGICAL INSTITUTION
# 3            BOGOTÁ D.C.               BOGOTA  TECHNOLOGICAL INSTITUTION
# 4           BOGOTÁ, D.C.               BOGOTA     UNIVERSITY INSTITUTION
#
#                  inst_origin  mod_reason_quantitat_point  \
# 0    OFFICIAL NATIONAL LEVEL                         9.6
# 1    OFFICIAL NATIONAL LEVEL                        10.8
# 2    OFFICIAL NATIONAL LEVEL                        10.6
# 3    OFFICIAL NATIONAL LEVEL                         9.3
# 4  NOT OFFICIAL - FOUNDATION                       145.0
#
#    mod_reading_review_point  mod_compete_citizen_point  mod_english_point  \
# 0                       8.3                        8.2                9.4
# 1                      10.1                       11.4                9.6
# 2                      11.2                       10.4                9.5
# 3                       8.2                        9.2                9.5
# 4                     179.0                      118.0              132.0
#
#    mod_communi_written_point your_state_research  your_inst_department_code  \
# 0                        9.4             TO POST                         11
# 1                       10.4             TO POST                         11
# 2                        9.9             TO POST                         11
# 3                        9.4             TO POST                         11
# 4                      138.0             TO POST                         11
#
#   your_type_of_document.1 your_nationality.1 your_gender.1 your_birthdate.1  \
# 0                      TI           COLOMBIA             M       30/07/1996
# 1                      CC           COLOMBIA             M       13/04/1994
# 2                      CC           COLOMBIA             F       08/12/1991
# 3                      TI           COLOMBIA             F       10/01/1996
# 4                      TI           COLOMBIA             M       11/10/1995
#
#    period.1 your_consecutive.1 your_student.1 your_country_resides.1  \
# 0     20122   SB11201220401680        STUDENT               COLOMBIA
# 1     20122   SB11201220585536        STUDENT               COLOMBIA
# 2     20122   SB11201220051348        STUDENT               COLOMBIA
# 3     20122   SB11201220372144        STUDENT               COLOMBIA
# 4     20132   SB11201320427497        STUDENT               COLOMBIA
#
#   your_dept_resides.1  your_dept_code_resides.1 your_municipality_resides.1  \
# 0              BOYACA                      15.0                    GUATEQUE
# 1            AMAZONAS                      91.0                     LETICIA
# 2           RISARALDA                      66.0                     PEREIRA
# 3             BOLIVAR                      13.0         CARTAGENA DE INDIAS
# 4        CUNDINAMARCA                      25.0                      SOACHA
#
#    your_municipality_code_resides.1     your_area_residse  \
# 0                           15322.0  Head of Municipality
# 1                           91001.0  Head of Municipality
# 2                           66001.0  Head of Municipality
# 3                           13001.0  Head of Municipality
# 4                           25754.0  Head of Municipality
#
#            your_tuition your_times_took_exam        fami_father_education.1  \
# 0  Does not pay Pension                  NaN                Graduate Degree
# 1  Does not pay Pension                  NaN         Middle School complete
# 2  Does not pay Pension                  NaN         Middle School complete
# 3  Does not pay Pension                  NaN  Undergraduate Degree complete
# 4  Does not pay Pension                Never         Middle School complete
#
#       fami_mother_education.1  \
# 0      Middle School complete
# 1      Middle School complete
# 2  Elementary school complete
# 3      Middle School complete
# 4  Elementary school complete
#
#                             fami_father_occupation.1  \
# 0                                        Businessman
# 1  Empleado con cargo como director o gerente gen...
# 2                                               Home
# 3      Employee with technical level or professional
# 4                       Other activity or occupation
#
#        fami_mother_occupation.1 fami_housing_stratum.1  \
# 0                   Businessman              Stratum 3
# 1                 Self-employed              Stratum 2
# 2                          Home              Stratum 2
# 3             Operator employee                    NaN
# 4  Other activity or occupation              Stratum 3
#
#   fami_social_stratum_sisben fami_house_members fami_house_rooms  \
# 0   Not classified by SISBEN               Four             Four
# 1   Not classified by SISBEN               Five            Three
# 2                    Level 2               Five            Three
# 3                    Level 1               Nine             Four
# 4   Not classified by SISBEN                Six             Four
#
#                               fami_house_floor fami_internet.1  \
# 0  Polished wood, tile, tablet, marble, carpet              Si
# 1                        Cement, gravel, brick              No
# 2                        Cement, gravel, brick              Si
# 3  Polished wood, tile, tablet, marble, carpet              No
# 4  Polished wood, tile, tablet, marble, carpet              Si
#
#   fami_computer.1 fami_washer fami_microwave fami_oven fami_automobile.1  \
# 0              Si          Si             Si        Si                Si
# 1              No          Si             No        No                No
# 2              Si          Si             Si        Si                No
# 3              No          No             No        No                No
# 4              Si          Si             Si        No                Si
#
#   fami_dvd fami_fridge.1 fami_mobile.1 fami_landline_phone.1  \
# 0       Si            Si            Si                    Si
# 1       Si            No            Si                    Si
# 2       Si            Si            Si                    Si
# 3       Si            No            Si                    No
# 4       Si            Si            Si                    Si
#
#            your_currently_working your_background your_expectations  \
# 0                              No              No               NaN
# 1  Yes, 20 hours or more per week              No               NaN
# 2                              No              Si               NaN
# 3                              No              No               NaN
# 4                              No              No                Si
#
#    cole_code_icfes  cole_dane_code_establishment  \
# 0           5207.0                  1.153220e+11
# 1          38919.0                  1.910010e+11
# 2          61424.0                  1.660010e+11
# 3           9110.0                  1.130010e+11
# 4         157636.0                  3.257540e+11
#
#                       cole_name_establishment cole_type   cole_nature  \
# 0                         I.E. VALLE DE TENZA     MIXED      OFFICIAL
# 1              I.E. INEM JOSE EUSTASIO RIVERA     MIXED      OFFICIAL
# 2                          IE AQUILINO BEDOYA     MIXED      OFFICIAL
# 3  INSTITUCION EDUCATIVA OLGA GONZALEZ ARRAUT     MIXED      OFFICIAL
# 4              LICEO NUESTRA SENORA MILAGROSA     MIXED  NOT OFFICIAL
#
#   cole_calendar cole_bilingual      cole_character  cole_dane_code_campus  \
# 0             A              N  TECHNICAL/ACADEMIC           1.153220e+11
# 1             A              N  TECHNICAL/ACADEMIC           1.910010e+11
# 2             A              N  TECHNICAL/ACADEMIC           1.660010e+11
# 3             A              N  TECHNICAL/ACADEMIC           1.130010e+11
# 4             A            NaN            ACADEMIC           3.257540e+11
#
#                                   cole_name_campus cole_main_campus  \
# 0             I.E. VALLE DE TENZA - SEDE PRINCIPAL              YES
# 1  I.E. INEM JOSE EUSTASIO RIVERA - SEDE PRINCIPAL              YES
# 2                         LIC CIAL AQUILINO BEDOYA              YES
# 3       INSTITUCION EDUCATIVA OLGA GONZALEZ ARRAUT              YES
# 4                   LICEO NUESTRA SENORA MILAGROSA              YES
#
#   cole_area_location cole_journey  cole_municipality_code_location  \
# 0              URBAN      MORNING                          15322.0
# 1              URBAN      MORNING                          91001.0
# 2              URBAN         LATE                          66001.0
# 3              URBAN         LATE                          13001.0
# 4              URBAN     COMPLETE                          25754.0
#
#   cole_municipality_location  cole_dept_code_location cole_dept_location  \
# 0                   GUATEQUE                     15.0             BOYACA
# 1                    LETICIA                     91.0           AMAZONAS
# 2                    PEREIRA                     66.0          RISARALDA
# 3        CARTAGENA DE INDIAS                     13.0            BOLIVAR
# 4                     SOACHA                     25.0       CUNDINAMARCA
#
#    score_language  score_mathematics  score_biology  score_chemistry  \
# 0            32.0               43.0           39.0             42.0
# 1            48.0               64.0           52.0             52.0
# 2            57.0               42.0           50.0             51.0
# 3            40.0               46.0           34.0             35.0
# 4            48.0               44.0           57.0             65.0
#
#    score_physical  score_social_science  score_philosophy  score_english  \
# 0            33.0                  33.0              29.0           38.0
# 1            54.0                  44.0              47.0           51.0
# 2            28.0                  46.0              45.0           43.0
# 3            45.0                  42.0              40.0           43.0
# 4            44.0                  49.0              43.0           42.0
#
#   performance_english                           go_deep  score_prof  \
# 0                  A-       SCORE_INTERDISC_ENVIRONMENT        49.0
# 1                  A1             SCORE_DEEPEN_LANGUAGE         6.0
# 2                  A-              SCORE_DEEPEN_BIOLOGY         5.0
# 3                  A-  SCORE_INTERDISC_VIOLENCE_AND_SOC        29.0
# 4                  A-       SCORE_INTERDISC_ENVIRONMENT        55.0
#
#   performance_prof  total_saber_score  total_saber_pro_score
# 0              NaN              338.0                   44.9
# 1               II              418.0                   52.3
# 2                I              367.0                   51.6
# 3              NaN              354.0                   45.6
# 4              NaN              447.0                  712.0

# %%
total_marks = ['total_saber_score', 'total_saber_pro_score']

# %% [markdown]
# # Scores by Municipality
#
# Note that some Municipalities are not as represented as the others, so municipalities that do not reach the 50th percentile will be dropped to avoid municipalities without enough data points.

# %%
saber_municipality = saber.copy()

# %%
saber_municipality_score = saber_municipality.groupby("your_municipality_resides").agg(['mean', 'count'])[total_marks]

# %%
threshold = saber_municipality['your_municipality_resides'].value_counts().describe()['50%']
print("The 50th percentile are municipalities that have {} instances in the dataset".format(threshold))
# Out:
# The 50th percentile are municipalities that have 15.0 instances in the dataset

# %%
saber_municipality_score = saber_municipality_score[saber_municipality_score['total_saber_score']['count'] > threshold]

# %%
top_50_saber = saber_municipality_score['total_saber_score']['mean'].sort_values(ascending=False).head(50)
bot_50_saber = saber_municipality_score['total_saber_score']['mean'].sort_values(ascending=False).tail(50)

# %%
plt.figure(figsize=(20,10))
plt.bar(top_50_saber.index, top_50_saber, label = 'Top 50')
plt.bar(bot_50_saber.index, bot_50_saber, label = 'Bottom 50')
plt.xticks(rotation=90)
plt.legend()
plt.title('Top 50 and Bottom 50 Municipalities by Saber 11 Scores')
# Out:
# Text(0.5, 1.0, 'Top 50 and Bottom 50 Municipalities by Saber 11 Scores')

# %%
top_50_saber_pro = saber_municipality_score['total_saber_pro_score']['mean'].sort_values(ascending=False).head(50)
bot_50_saber_pro = saber_municipality_score['total_saber_pro_score']['mean'].sort_values(ascending=False).tail(50)

# %%
plt.figure(figsize=(20,10))
plt.bar(top_50_saber_pro.index, top_50_saber_pro, label = 'Top 50')
plt.bar(bot_50_saber_pro.index, bot_50_saber_pro, label = 'Bottom 50')
plt.xticks(rotation=90)
plt.legend()
plt.title('Top 50 and Bottom 50 Municipalities by Saber Pro Scores')
# Out:
# Text(0.5, 1.0, 'Top 50 and Bottom 50 Municipalities by Saber Pro Scores')

# %% [markdown]
# From the two graphs, we see that there is a great mean score difference between the Top 50 and Bottom 50 Municipalities. There is an even greater difference in Saber Pro. We will explore these differences by first examining the factors that affect mean saber scores.

# %%
saber_top_50_municipalities = top_50_saber.index.to_list()
saber_bot_50_municipalities = bot_50_saber.index.to_list()
saber_pro_top_50_municipalities = top_50_saber_pro.index.to_list()
saber_pro_bot_50_municipalities = bot_50_saber_pro.index.to_list()

# %%
saber_top_50_municipalities_as_set = set(saber_top_50_municipalities)
saber_top_50_intersection = saber_top_50_municipalities_as_set.intersection(saber_pro_top_50_municipalities)
saber_top_50_intersection_list = list(saber_top_50_intersection)

print("\n There are {} municipalities in the saber and saber pro Top 50.".format(len(saber_top_50_intersection_list)))
print("\n These municipalities are {}".format(saber_top_50_intersection_list))

saber_bot_50_municipalities_as_set = set(saber_bot_50_municipalities)
saber_bot_50_intersection = saber_bot_50_municipalities_as_set.intersection(saber_pro_bot_50_municipalities)
saber_bot_50_intersection_list = list(saber_bot_50_intersection)

print("\n There are {} municipalities in the saber and saber pro Bot 50. \n".format(len(saber_bot_50_intersection_list)))
print("\n These municipalities are {}".format(saber_bot_50_intersection_list))
# Out:
#  There are 27 municipalities in the saber and saber pro Top 50.
#
#  These municipalities are ['PASTO', 'SAN DIEGO', 'TUNJA', 'FLORIDABLANCA', 'ENVIGADO', 'CAJICÁ', 'RETIRO', 'TENJO', 'CHÍA', 'LA CALERA', 'BUCARAMANGA', 'MIRANDA', 'SABANETA', 'COTA', 'BOGOTÁ, D.C.', 'MONTERÍA', 'PUERTO COLOMBIA', 'CERETÉ', 'MACEO', 'RAMIRIQUÍ', 'CALI', 'SOPÓ', 'JAMUNDÍ', 'TANGUA', 'PALMIRA', 'SORACÁ', 'EXTRANJERO']
#
#  There are 14 municipalities in the saber and saber pro Bot 50.
#
#
#  These municipalities are ['SANTA FÉ DE ANTIOQUIA', 'PUERTO CARREÑO', 'SAMANÁ', 'CERRITO', 'COYAIMA', 'TADÓ', 'URRAO', 'FREDONIA', 'MESETAS', 'BUENOS AIRES', 'SUPÍA', 'TOCAIMA', 'GUÁTICA', 'PUERTO BERRÍO']

# %% [markdown]
# We will be taking note of these municipalities as we explore the factors that affect mean saber and saber pro scores.

# %% [markdown]
# ## Scores by Social Factors

# %%
saber.columns.to_list()
# Out:
# ['your_type_of_document',
#  'your_nationality',
#  'your_gender',
#  'your_birthdate',
#  'your_exterior',
#  'period',
#  'your_consecutive',
#  'your_marital_status',
#  'your_student',
#  'your_country_resides',
#  'your_have_ethnicity',
#  'your_dept_resides',
#  'your_dept_code_resides',
#  'your_municipality_resides',
#  'your_municipality_code_resides',
#  'your_high_school_degree',
#  'your_year_exam_sb11',
#  'your_semester_exam__b11',
#  'your_percentage_credits_approved',
#  'your_tuition_cost_university',
#  'your_tuition_pymt_scholarship',
#  'your_tuition_pymt_credit',
#  'your_tuition_pymt_parents',
#  'your_tuition_pymt_yourself',
#  'your_i_take_course_preparation',
#  'your_course_teacher_ies',
#  'your_course_external_support_ies',
#  'your_course_external_ies',
#  'your_simulation_type_icfes',
#  'your_activity_strengths_areas',
#  'your_activity_strengths_generic',
#  'your_on_semester',
#  'fami_current_household_type',
#  'fami_is_the_head_family',
#  'fami_econ_dependents',
#  'fami_father_education',
#  'fami_mother_education',
#  'fami_father_occupation',
#  'fami_mother_occupation',
#  'fami_father_work',
#  'fami_mother_work',
#  'fami_housing_stratum',
#  'fami_social_stratum_sisben_y',
#  'fami_internet',
#  'fami_computer',
#  'fami_have_oven',
#  'fami_automobile',
#  'fami_fridge',
#  'fami_mobile',
#  'fami_num_books',
#  'fami_landline_phone',
#  'fami_monthly_family_income',
#  'your_works_currently',
#  'inst_institution_code',
#  'inst_institution_name',
#  'your_prgm_academic',
#  'your_prgm_academic_snies',
#  'group_reference',
#  'your_prgm_municipality_code',
#  'your_prgm_municipality',
#  'your_prgm_department',
#  'your_prgm_academic_level',
#  'your_prgm_method',
#  'your_undergraduate_core',
#  'your_inst_municipality_code',
#  'your_inst_municipality',
#  'your_inst_department',
#  'inst_character_academic',
#  'inst_origin',
#  'mod_reason_quantitat_point',
#  'mod_reading_review_point',
#  'mod_compete_citizen_point',
#  'mod_english_point',
#  'mod_communi_written_point',
#  'your_state_research',
#  'your_inst_department_code',
#  'your_type_of_document.1',
#  'your_nationality.1',
#  'your_gender.1',
#  'your_birthdate.1',
#  'period.1',
#  'your_consecutive.1',
#  'your_student.1',
#  'your_country_resides.1',
#  'your_dept_resides.1',
#  'your_dept_code_resides.1',
#  'your_municipality_resides.1',
#  'your_municipality_code_resides.1',
#  'your_area_residse',
#  'your_tuition',
#  'your_times_took_exam',
#  'fami_father_education.1',
#  'fami_mother_education.1',
#  'fami_father_occupation.1',
#  'fami_mother_occupation.1',
#  'fami_housing_stratum.1',
#  'fami_social_stratum_sisben',
#  'fami_house_members',
#  'fami_house_rooms',
#  'fami_house_floor',
#  'fami_internet.1',
#  'fami_computer.1',
#  'fami_washer',
#  'fami_microwave',
#  'fami_oven',
#  'fami_automobile.1',
#  'fami_dvd',
#  'fami_fridge.1',
#  'fami_mobile.1',
#  'fami_landline_phone.1',
#  'your_currently_working',
#  'your_background',
#  'your_expectations',
#  'cole_code_icfes',
#  'cole_dane_code_establishment',
#  'cole_name_establishment',
#  'cole_type',
#  'cole_nature',
#  'cole_calendar',
#  'cole_bilingual',
#  'cole_character',
#  'cole_dane_code_campus',
#  'cole_name_campus',
#  'cole_main_campus',
#  'cole_area_location',
#  'cole_journey',
#  'cole_municipality_code_location',
#  'cole_municipality_location',
#  'cole_dept_code_location',
#  'cole_dept_location',
#  'score_language',
#  'score_mathematics',
#  'score_biology',
#  'score_chemistry',
#  'score_physical',
#  'score_social_science',
#  'score_philosophy',
#  'score_english',
#  'performance_english',
#  'go_deep',
#  'score_prof',
#  'performance_prof',
#  'total_saber_score',
#  'total_saber_pro_score']

# %%
total_marks = ['total_saber_score', 'total_saber_pro_score']

social_factors = ['your_gender', 'your_i_take_course_preparation', 'your_course_teacher_ies', "your_course_external_support_ies", 'your_course_external_ies', 
                  'your_simulation_type_icfes', 'your_activity_strengths_generic', 'fami_housing_stratum', 'fami_social_stratum_sisben_y', 'fami_monthly_family_income', 'fami_internet',
                  'fami_computer', 'fami_have_oven', 'fami_automobile', 'fami_fridge', 'fami_mobile', 'fami_num_books', 'fami_landline_phone', 'fami_father_education', 'fami_mother_education',
                  'fami_father_occupation', 'fami_mother_occupation', 'fami_father_work','fami_mother_work']

# %%
cols = 3
rows = len(social_factors) // cols+1
fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(30,30))
plt.subplots_adjust(hspace = 2.0)

axe=axs.ravel()

counter = 0

for i in social_factors:
    saber.groupby(saber[i]).mean()[total_marks].plot.bar(ax=axe[counter])
    counter += 1
# Out:
# c:\users\gerson cruz\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %% [markdown]
# Based on the results of the graphs above, the following insights are gained:
#
# *Note that the insights are for the MEAN TOTAL SCORES. Insights may differ per subject area or the like. Nonetheless, for overall mean scores for Saber 11 and Saber Pro, these insights are generated.*
#
# **For Saber 11 ICFES**
# - There is no correlation amongst all the social factors and Saber 11 scores. The scores remain consistent throughout 'Yes' or 'No' answers and other categorical options like 'Occupation' and 'Education of parents. There are no stark outliers observered.
# - Since there are no stark outliers observed from the 'mean', other levels of aggregations are recommended.
#
# **For Saber 11 Pro**
# - The following features have a considerable effect to Saber 11 Pro scores.
#     - Took a  special preparation test?
#     - Took another test that's not lectured by the government?
#     - Did you did a simulacrum
#     - Generic Preparation for Test
#     - House Stratum
#     - Family has internet?
#     - Do you have a computer?
#     - Do you have a car?
#     - Father's education
#     - Mother's education
#     - Father's Occupation
#     - Mother's Job occupation
#
# **For Saber 11 and Saber 11 Pro**
# - 'Did student took preparation test' appears to not matter. Whether the student took or not does not change his/her scores.
# - 'Sisben level' appears to not matter. The sisben level does not affect overall scores.
# - 'Mensual income' appears to not matter. The monthly income level does not affect overall scores.
# - kiln, fridge, cellphone, books, and cellphone appear to not matter. Whether one has them or not does not affect overall scores.

# %% [markdown]
# **Now we have found out Saber 11 Pro has the more variance visually, we tie this back to the municipality question: Are the high and low scores of these municipalities affected by these social factors?**

# %%
saber_pro_top_50 = saber.loc[saber['your_municipality_resides'].isin(saber_pro_top_50_municipalities)]
print("There are {} datapoints in the saber dataset for all top 50 municipalities".format(saber_pro_top_50.shape[0]))

saber_pro_bot_50 = saber.loc[saber['your_municipality_resides'].isin(saber_pro_bot_50_municipalities)]
print("There are {} datapoints in the saber dataset for all bot 50 municipalities".format(saber_pro_bot_50.shape[0]))
# Out:
# There are 54195 datapoints in the saber dataset for all top 50 municipalities
# There are 2258 datapoints in the saber dataset for all bot 50 municipalities

# %%
relevant_social_factors = ['your_course_teacher_ies', "your_course_external_support_ies", 'your_course_external_ies', 
                           'your_simulation_type_icfes', 'your_activity_strengths_generic', 'fami_housing_stratum', 'fami_internet',
                           'fami_computer', 'fami_automobile', 'fami_father_education', 'fami_mother_education',
                           'fami_father_work','fami_mother_work']

# %% [markdown]
# ## Top 50 Municipalities Saber Pro

# %%
cols = 3
rows = len(relevant_social_factors) // cols+1
fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(30,30))
plt.subplots_adjust(hspace = 2.0)

axe=axs.ravel()

counter = 0

for i in relevant_social_factors:
    saber_pro_top_50.groupby(saber_pro_top_50[i])['total_saber_pro_score'].count().plot.bar(ax=axe[counter])
    counter += 1

# %% [markdown]
# ## Bottom 50 Municipalities Saber Pro

# %%
cols = 3
rows = len(relevant_social_factors) // cols+1
fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(30,30))
plt.subplots_adjust(hspace = 5.0)

axe=axs.ravel()

counter = 0

for i in relevant_social_factors:
    saber_pro_bot_50.groupby(saber_pro_bot_50[i])['total_saber_pro_score'].count().plot.bar(ax=axe[counter])
    counter += 1

# %% [markdown]
# # Insights
#
# ### For the Top 50 Municipalities in terms of Saber Pro scores:
# 1. With regard to taking special preparation tests, simulacrums, and the generic preparation. It appears these factors do not affect as much the overall saber scores of the students as the highest number for each feature still correspond to not taking these tests.
# 2. Majority of the students have computers and internet at home. These two features then are relevant to the dataset.
# 3. Both the mother and father of students belonging to these municipalities have, in majority, finished at least secondary education.
# 4. The father and mother of students belonging to these municipalities have, in majority, have employment belonging to Obrero o empleyado and trabajador por cuenta propia.
#
# ### For the Bottom 50 Municipalities in terms of Saber Pro scores:
# 1. Majority of the students belonging to these municipalities were not able to take any preparation tests and it led to lower Saber Pro scores.
# 2. Majority of the students have computers but no access to the internet. This may cause a decrease in Saber pro scores.
# 3. Majority of the students' families belong to Estrata 1 house level, the lowest house levels in Colombia.
# 4. A lot of parents in these municipalities have not finished primary school, and at maximum, only completed Secondary School. This shows a stark divide between the top 50 and the bottom 50.
# 5. The father's of students belong to the class of pequeno empresário and trabajador por cuenta propia. However, majority of the mother's have jobs at Hogar (Home) which indicates the father is the one earning unlike in Top 50 municipalities where both parents are earning.
#
# #### Overall, based on the current analysis, we see that the factors of taking preparation tests, father's education, mother's education, father's occupation, mother's occupation, house stratum, and access to the internet have a greater impact of decreasing scores. Without these factors, Saber Pro scores of students decrease. There is, then, a stark divide shown between the Top and Bottom Municipalities when it comes to Saber Pro scores.

# %% [markdown]
# ### Next Steps:
#
# 1. Formulate more questions to visualize the colombian student population.
# 2. Determine whether there are more social factors that affect students test scores.
# 3. Relate these social factors to whether the Saber scores become accurate to the current academic program of the student. Ask the question: Are these social factors hindering the student in pursuing the program to which he is most logically belonging to?

# %% [markdown]
# #### Question: Does high school education affect total scores?

# %%
saber.groupby('your_high_school_degree')[total_marks].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='your_high_school_degree'>

# %% [markdown]
# It appears students who had a high school degree of superior normalist and technical bachelor have substantially lower saber pro scores. Why?

# %% [markdown]
# ### Superior Normalist

# %%
hs_degree = ['Superior Normalist']
superior_normalist_saber_pro = saber.loc[saber['your_high_school_degree'].isin(hs_degree)]

# %%
superior_normalist_saber_pro
# Out:
#        your_type_of_document your_nationality your_gender your_birthdate  \
# 306                       TI         COLOMBIA           M     24/08/1994
# 308                       CC         COLOMBIA           F     15/02/1996
# 362                       CC         COLOMBIA           F     31/10/1995
# 429                       CC         COLOMBIA           F     21/05/1995
# 438                       TI         COLOMBIA           F     23/08/1996
# ...                      ...              ...         ...            ...
# 211405                    TI         COLOMBIA           F     27/06/1995
# 211406                    TI         COLOMBIA           F     20/05/1996
# 211633                    CC         COLOMBIA           F     23/07/1983
# 211914                    TI         COLOMBIA           F     28/06/1996
# 211939                    TI         COLOMBIA           M     05/01/1996
#
#        your_exterior  period your_consecutive your_marital_status  \
# 306              NaN   20143   EK201430174278              Single
# 308              NaN   20143   EK201430257099              Single
# 362              NaN   20152   EK201520056387              Single
# 429              NaN   20143   EK201430168120              Single
# 438              NaN   20143   EK201430235690              Single
# ...              ...     ...              ...                 ...
# 211405           NaN   20143   EK201430049437              Single
# 211406           NaN   20143   EK201430223274              Single
# 211633           NaN   20142   EK201420083665              Single
# 211914           NaN   20143   EK201430111507              Single
# 211939           NaN   20143   EK201430215047              Single
#
#        your_student your_country_resides your_have_ethnicity  \
# 306         STUDENT             COLOMBIA                 NaN
# 308         STUDENT             COLOMBIA                 NaN
# 362         STUDENT             COLOMBIA                 NaN
# 429         STUDENT             COLOMBIA                 NaN
# 438         STUDENT             COLOMBIA                 NaN
# ...             ...                  ...                 ...
# 211405      STUDENT             COLOMBIA                 NaN
# 211406      STUDENT             COLOMBIA                 NaN
# 211633      STUDENT             COLOMBIA                 NaN
# 211914      STUDENT             COLOMBIA                 NaN
# 211939      STUDENT             COLOMBIA                 NaN
#
#        your_dept_resides  your_dept_code_resides your_municipality_resides  \
# 306               NARIÑO                    52.0                 SAN PABLO
# 308            SANTANDER                    68.0           BARRANCABERMEJA
# 362               CALDAS                    17.0                 MANIZALES
# 429               CALDAS                    17.0                 MANIZALES
# 438              QUINDIO                    63.0                   ARMENIA
# ...                  ...                     ...                       ...
# 211405         ATLANTICO                     8.0              BARRANQUILLA
# 211406            NARIÑO                    52.0                     PASTO
# 211633         SANTANDER                    68.0               BUCARAMANGA
# 211914      CUNDINAMARCA                    25.0                    SOACHA
# 211939         MAGDALENA                    47.0               SANTA MARTA
#
#         your_municipality_code_resides your_high_school_degree  \
# 306                            52693.0      Superior Normalist
# 308                            68081.0      Superior Normalist
# 362                            17001.0      Superior Normalist
# 429                            17001.0      Superior Normalist
# 438                            63001.0      Superior Normalist
# ...                                ...                     ...
# 211405                          8001.0      Superior Normalist
# 211406                         52001.0      Superior Normalist
# 211633                         68001.0      Superior Normalist
# 211914                         25754.0      Superior Normalist
# 211939                         47001.0      Superior Normalist
#
#         your_year_exam_sb11 your_semester_exam__b11  \
# 306                  2012.0            2nd semester
# 308                  2012.0            2nd semester
# 362                  2012.0            2nd semester
# 429                  2012.0            2nd semester
# 438                  2012.0            1st semester
# ...                     ...                     ...
# 211405               2012.0            1st semester
# 211406               2012.0            2nd semester
# 211633               2012.0            2nd semester
# 211914               2012.0            2nd semester
# 211939               2012.0            2nd semester
#
#        your_percentage_credits_approved  \
# 306                                 NaN
# 308                                 NaN
# 362                 Between 81% and 90%
# 429                                 NaN
# 438                                 NaN
# ...                                 ...
# 211405                              NaN
# 211406                              NaN
# 211633                    More than 90%
# 211914                              NaN
# 211939                              NaN
#
#                      your_tuition_cost_university  \
# 306                                           NaN
# 308                                           NaN
# 362     Between 1 million and less than 3 million
# 429                                           NaN
# 438                                           NaN
# ...                                           ...
# 211405                                        NaN
# 211406                                        NaN
# 211633  Between 1 million and less than 3 million
# 211914                                        NaN
# 211939                                        NaN
#
#        your_tuition_pymt_scholarship your_tuition_pymt_credit  \
# 306                              NaN                      NaN
# 308                              NaN                      NaN
# 362                              NaN                       Si
# 429                              NaN                      NaN
# 438                              NaN                      NaN
# ...                              ...                      ...
# 211405                           NaN                      NaN
# 211406                           NaN                      NaN
# 211633                            Si                       No
# 211914                           NaN                      NaN
# 211939                           NaN                      NaN
#
#        your_tuition_pymt_parents your_tuition_pymt_yourself  \
# 306                          NaN                        NaN
# 308                          NaN                        NaN
# 362                          NaN                        NaN
# 429                          NaN                        NaN
# 438                          NaN                        NaN
# ...                          ...                        ...
# 211405                       NaN                        NaN
# 211406                       NaN                        NaN
# 211633                        No                         No
# 211914                       NaN                        NaN
# 211939                       NaN                        NaN
#
#        your_i_take_course_preparation   your_course_teacher_ies  \
# 306                                No  He did not take a course
# 308                                No  He did not take a course
# 362                                No  He did not take a course
# 429                                No  He did not take a course
# 438                                No  He did not take a course
# ...                               ...                       ...
# 211405                             No  He did not take a course
# 211406                             No  He did not take a course
# 211633                             No  He did not take a course
# 211914                             No  He did not take a course
# 211939                             No  He did not take a course
#
#        your_course_external_support_ies your_course_external_ies  \
# 306            He did not take a course            No tomó curso
# 308            He did not take a course            No tomó curso
# 362            He did not take a course            No tomó curso
# 429            He did not take a course            No tomó curso
# 438            He did not take a course            No tomó curso
# ...                                 ...                      ...
# 211405         He did not take a course            No tomó curso
# 211406         He did not take a course            No tomó curso
# 211633         He did not take a course            No tomó curso
# 211914         He did not take a course            No tomó curso
# 211939         He did not take a course            No tomó curso
#
#        your_simulation_type_icfes your_activity_strengths_areas  \
# 306                            No                            No
# 308                            No                            No
# 362                            No                            No
# 429                            No                            No
# 438                            No                            No
# ...                           ...                           ...
# 211405                         No                            No
# 211406                         No                            No
# 211633                         No                            No
# 211914                         No                            No
# 211939                         No                            No
#
#        your_activity_strengths_generic  your_on_semester  \
# 306                                 No               NaN
# 308                                 No               NaN
# 362                                 No               5.0
# 429                                 No               NaN
# 438                                 No               NaN
# ...                                ...               ...
# 211405                              No               NaN
# 211406                              No               NaN
# 211633                              No               3.0
# 211914                              No               NaN
# 211939                              No               NaN
#
#                        fami_current_household_type fami_is_the_head_family  \
# 306     It is temporary for study or other reasons                      No
# 308                    It is habitual or permanent                      No
# 362                    It is habitual or permanent                      No
# 429                    It is habitual or permanent                      No
# 438                    It is habitual or permanent                      No
# ...                                            ...                     ...
# 211405                 It is habitual or permanent                      No
# 211406                 It is habitual or permanent                      No
# 211633                 It is habitual or permanent                      Si
# 211914                 It is habitual or permanent                      No
# 211939                 It is habitual or permanent                      No
#
#        fami_econ_dependents         fami_father_education  \
# 306                    None  Elementary school incomplete
# 308                    None                          None
# 362                    None        Middle School complete
# 429                    None     Technical School complete
# 438                     One        Middle School complete
# ...                     ...                           ...
# 211405                  Two        Middle School complete
# 211406                 None   Technical School incomplete
# 211633                  One  Elementary school incomplete
# 211914                 None      Middle School incomplete
# 211939                 None   Technical School incomplete
#
#                fami_mother_education        fami_father_occupation  \
# 306           Middle School complete                 Self-employed
# 308     Elementary school incomplete  Other activity or occupation
# 362         Middle School incomplete                     Pensioner
# 429           Middle School complete             Operator employee
# 438           Middle School complete             Operator employee
# ...                              ...                           ...
# 211405        Middle School complete                     Pensioner
# 211406               Graduate Degree                 Self-employed
# 211633      Middle School incomplete             Operator employee
# 211914   Technical School incomplete             Operator employee
# 211939      Middle School incomplete                 Self-employed
#
#                                fami_mother_occupation fami_father_work  \
# 306                      Other activity or occupation              NaN
# 308                                              Home              NaN
# 362                      Other activity or occupation              NaN
# 429                                 Operator employee              NaN
# 438                                              Home              NaN
# ...                                               ...              ...
# 211405                                  Self-employed              NaN
# 211406  Employee with technical level or professional              NaN
# 211633                              Operator employee              NaN
# 211914                                           Home              NaN
# 211939                                           Home              NaN
#
#        fami_mother_work fami_housing_stratum fami_social_stratum_sisben_y  \
# 306                 NaN            Stratum 1                      Level 3
# 308                 NaN            Stratum 1                      Level 1
# 362                 NaN            Stratum 3     Not classified by SISBEN
# 429                 NaN            Stratum 3     Not classified by SISBEN
# 438                 NaN            Stratum 2                      Level 2
# ...                 ...                  ...                          ...
# 211405              NaN            Stratum 3     Not classified by SISBEN
# 211406              NaN            Stratum 2     Not classified by SISBEN
# 211633              NaN            Stratum 1                      Level 1
# 211914              NaN            Stratum 2     Not classified by SISBEN
# 211939              NaN            Stratum 2     Not classified by SISBEN
#
#        fami_internet fami_computer fami_have_oven fami_automobile fami_fridge  \
# 306               No            Si             No              No          Si
# 308               Si            Si             No              No          Si
# 362               Si            Si             Si              Si          Si
# 429               Si            Si             No              No          Si
# 438               Si            Si             Si              No          Si
# ...              ...           ...            ...             ...         ...
# 211405            Si            Si             No              No          Si
# 211406            Si            Si             Si              No          Si
# 211633            Si            Si             No              No          Si
# 211914            Si            Si             No              No          Si
# 211939            Si            Si             No              No          Si
#
#        fami_mobile fami_num_books fami_landline_phone  \
# 306             Si            NaN                  No
# 308             Si            NaN                  Si
# 362             Si            NaN                  Si
# 429             Si            NaN                  Si
# 438             Si            NaN                  No
# ...            ...            ...                 ...
# 211405          Si            NaN                  Si
# 211406          Si            NaN                  Si
# 211633          No            NaN                  Si
# 211914          Si            NaN                  Si
# 211939          Si            NaN                  Si
#
#             fami_monthly_family_income  \
# 306                   Less than 1 SMLV
# 308                   Less than 1 SMLV
# 362     Between 2 and less than 3 SMLV
# 429     Between 2 and less than 3 SMLV
# 438     Between 1 and less than 2 SMLV
# ...                                ...
# 211405  Between 5 and less than 7 SMLV
# 211406  Between 3 and less than 5 SMLV
# 211633  Between 1 and less than 2 SMLV
# 211914  Between 2 and less than 3 SMLV
# 211939  Between 2 and less than 3 SMLV
#
#                                      your_works_currently  \
# 306                                                    No
# 308                                                    No
# 362                                                    No
# 429                                                    No
# 438                                                    No
# ...                                                   ...
# 211405                                                 No
# 211406                                                 No
# 211633                                                 No
# 211914                                                 No
# 211939  Yes, to help pay their tuition and/or househol...
#
#         inst_institution_code  \
# 306                     11890
# 308                     14548
# 362                      1722
# 429                      6197
# 438                     12922
# ...                       ...
# 211405                   3590
# 211406                  11486
# 211633                   4829
# 211914                  24158
# 211939                  10421
#
#                                     inst_institution_name  \
# 306     NORMAL SUPERIOR SAGRADO CORAZON DE JESUS-SAN P...
# 308     ESCUELA NORMAL SUPERIOR CRISTO REY-BARRANCABER...
# 362                    UNIVERSIDAD DE MANIZALES-MANIZALES
# 429     INSTITUCIÓN EDUCATIVA NORMAL SUP DE MANIZALES-...
# 438                       ESCUELA NORMAL SUPERIOR-ARMENIA
# ...                                                   ...
# 211405  ESCUELA NORMAL SUPERIOR DEL DISTRITO BARRANQUI...
# 211406  I.E.M. NORMAL SUPERIOR DE PASTO - SEDE PRINCIP...
# 211633  CORPORACION INTERAMERICANA DE EDUCACION SUPERI...
# 211914  ESC. NORMAL SUPERIOR DISTRITAL MARIA MONTESSOR...
# 211939   ESCUELA NORMAL SAN PEDRO ALEJANDRINO-SANTA MARTA
#
#                                        your_prgm_academic  \
# 306     CICLO COMPLEMENTARIO DE ESCUELAS NORMALES SUPE...
# 308     CICLO COMPLEMENTARIO DE ESCUELAS NORMALES SUPE...
# 362                                TECNOLOGIA INFORMATICA
# 429     CICLO COMPLEMENTARIO DE ESCUELAS NORMALES SUPE...
# 438     CICLO COMPLEMENTARIO DE ESCUELAS NORMALES SUPE...
# ...                                                   ...
# 211405  CICLO COMPLEMENTARIO DE ESCUELAS NORMALES SUPE...
# 211406  CICLO COMPLEMENTARIO DE ESCUELAS NORMALES SUPE...
# 211633                       TECNICA PROFESIONAL CONTABLE
# 211914  CICLO COMPLEMENTARIO DE ESCUELAS NORMALES SUPE...
# 211939  CICLO COMPLEMENTARIO DE ESCUELAS NORMALES SUPE...
#
#         your_prgm_academic_snies                      group_reference  \
# 306                          NaN                  NORMALES SUPERIORES
# 308                          NaN                  NORMALES SUPERIORES
# 362                      53383.0                   TECNOLOGICO EN TIC
# 429                          NaN                  NORMALES SUPERIORES
# 438                          NaN                  NORMALES SUPERIORES
# ...                          ...                                  ...
# 211405                       NaN                  NORMALES SUPERIORES
# 211406                       NaN                  NORMALES SUPERIORES
# 211633                   54010.0  TECNICO EN ADMINISTRACIÓN Y TURISMO
# 211914                       NaN                  NORMALES SUPERIORES
# 211939                       NaN                  NORMALES SUPERIORES
#
#         your_prgm_municipality_code your_prgm_municipality  \
# 306                           52693              SAN PABLO
# 308                           68081        BARRANCABERMEJA
# 362                           17001              MANIZALES
# 429                           17001              MANIZALES
# 438                           63001                ARMENIA
# ...                             ...                    ...
# 211405                         8001           BARRANQUILLA
# 211406                        52001                  PASTO
# 211633                        68001            BUCARAMANGA
# 211914                        11001            BOGOTÁ D.C.
# 211939                        47001            SANTA MARTA
#
#        your_prgm_department your_prgm_academic_level your_prgm_method  \
# 306                  NARIÑO               TECHNOLOGY        IN PERSON
# 308               SANTANDER               TECHNOLOGY        IN PERSON
# 362                  CALDAS               TECHNOLOGY         DISTANCE
# 429                  CALDAS               TECHNOLOGY        IN PERSON
# 438                 QUINDIO               TECHNOLOGY        IN PERSON
# ...                     ...                      ...              ...
# 211405            ATLANTICO               TECHNOLOGY        IN PERSON
# 211406               NARIÑO               TECHNOLOGY        IN PERSON
# 211633            SANTANDER  PROFESSIONAL TECHNICIAN        IN PERSON
# 211914               BOGOTA               TECHNOLOGY        IN PERSON
# 211939            MAGDALENA               TECHNOLOGY        IN PERSON
#
#                          your_undergraduate_core  your_inst_municipality_code  \
# 306                             SUPERIOR NORMALS                        52693
# 308                             SUPERIOR NORMALS                        68081
# 362     COMPUTER SYSTEMS, TELEMATICS ENGINEERING                        17001
# 429                             SUPERIOR NORMALS                        17001
# 438                             SUPERIOR NORMALS                        63001
# ...                                          ...                          ...
# 211405                          SUPERIOR NORMALS                         8001
# 211406                          SUPERIOR NORMALS                        52001
# 211633                         PUBLIC ACCOUNTING                        68001
# 211914                          SUPERIOR NORMALS                        11001
# 211939                          SUPERIOR NORMALS                        47001
#
#        your_inst_municipality your_inst_department  \
# 306                 SAN PABLO               NARIÑO
# 308           BARRANCABERMEJA            SANTANDER
# 362                 MANIZALES               CALDAS
# 429                 MANIZALES               CALDAS
# 438                   ARMENIA              QUINDIO
# ...                       ...                  ...
# 211405           BARRANQUILLA            ATLANTICO
# 211406                  PASTO               NARIÑO
# 211633            BUCARAMANGA            SANTANDER
# 211914            BOGOTÁ D.C.               BOGOTA
# 211939            SANTA MARTA            MAGDALENA
#
#               inst_character_academic                 inst_origin  \
# 306            NORMAL SUPERIOR SCHOOL              SPECIAL REGIME
# 308            NORMAL SUPERIOR SCHOOL              SPECIAL REGIME
# 362                        UNIVERSITY   NOT OFFICIAL - FOUNDATION
# 429            NORMAL SUPERIOR SCHOOL              SPECIAL REGIME
# 438            NORMAL SUPERIOR SCHOOL              SPECIAL REGIME
# ...                               ...                         ...
# 211405         NORMAL SUPERIOR SCHOOL              SPECIAL REGIME
# 211406         NORMAL SUPERIOR SCHOOL              SPECIAL REGIME
# 211633  PROFESSIONAL TECHNICAL SCHOOL  NOT OFFICIAL - CORPORATION
# 211914         NORMAL SUPERIOR SCHOOL              SPECIAL REGIME
# 211939         NORMAL SUPERIOR SCHOOL              SPECIAL REGIME
#
#         mod_reason_quantitat_point  mod_reading_review_point  \
# 306                            8.8                       8.5
# 308                            9.9                      13.0
# 362                           12.5                      11.2
# 429                           10.3                      10.4
# 438                           10.0                       9.9
# ...                            ...                       ...
# 211405                         9.5                       9.5
# 211406                        10.5                       9.6
# 211633                        10.2                       9.6
# 211914                         9.5                       9.7
# 211939                        10.5                       8.0
#
#         mod_compete_citizen_point  mod_english_point  \
# 306                           8.1                9.9
# 308                          11.3               14.4
# 362                          11.2               13.6
# 429                           9.7               11.5
# 438                           9.2                9.9
# ...                           ...                ...
# 211405                        8.7                9.2
# 211406                        8.6               10.2
# 211633                        9.5                9.2
# 211914                        9.5               10.6
# 211939                        9.1                9.8
#
#         mod_communi_written_point your_state_research  \
# 306                          8.40             TO POST
# 308                         11.10             TO POST
# 362                         11.38             TO POST
# 429                          8.50             TO POST
# 438                         10.20             TO POST
# ...                           ...                 ...
# 211405                       9.00             TO POST
# 211406                       9.50             TO POST
# 211633                       7.20             TO POST
# 211914                      11.00             TO POST
# 211939                       9.00             TO POST
#
#         your_inst_department_code your_type_of_document.1 your_nationality.1  \
# 306                            52                      TI           COLOMBIA
# 308                            68                      TI           COLOMBIA
# 362                            17                      TI           COLOMBIA
# 429                            17                      TI           COLOMBIA
# 438                            63                      TI           COLOMBIA
# ...                           ...                     ...                ...
# 211405                          8                      TI           COLOMBIA
# 211406                         52                      TI           COLOMBIA
# 211633                         68                      CC           COLOMBIA
# 211914                         11                      TI           COLOMBIA
# 211939                         47                      TI           COLOMBIA
#
#        your_gender.1 your_birthdate.1  period.1 your_consecutive.1  \
# 306                M       24/08/1994     20122   SB11201220585020
# 308                F       15/02/1996     20122   SB11201220013666
# 362                F       31/10/1995     20122   SB11201220571130
# 429                F       21/05/2002     20122   SB11201220408467
# 438                F       23/08/1996     20122   SB11201220202182
# ...              ...              ...       ...                ...
# 211405             F       27/06/1995     20122   SB11201220515039
# 211406             F       20/05/1996     20122   SB11201220171380
# 211633             F       23/07/1983     20122   SB11201220005177
# 211914             F       28/06/1996     20122   SB11201220578004
# 211939             M       05/01/1996     20122   SB11201220493642
#
#        your_student.1 your_country_resides.1 your_dept_resides.1  \
# 306           STUDENT               COLOMBIA               CAUCA
# 308           STUDENT               COLOMBIA           SANTANDER
# 362           STUDENT               COLOMBIA              CALDAS
# 429           STUDENT               COLOMBIA              CALDAS
# 438           STUDENT               COLOMBIA                 NaN
# ...               ...                    ...                 ...
# 211405        STUDENT               COLOMBIA           ATLANTICO
# 211406        STUDENT               COLOMBIA              NARIÑO
# 211633        STUDENT               COLOMBIA                 NaN
# 211914        STUDENT               COLOMBIA        CUNDINAMARCA
# 211939        STUDENT               COLOMBIA           MAGDALENA
#
#         your_dept_code_resides.1 your_municipality_resides.1  \
# 306                         19.0                     BOLÍVAR
# 308                         68.0             BARRANCABERMEJA
# 362                         17.0                   MANIZALES
# 429                         17.0                   MANIZALES
# 438                          NaN                         NaN
# ...                          ...                         ...
# 211405                       8.0                BARRANQUILLA
# 211406                      52.0                       PASTO
# 211633                       NaN                         NaN
# 211914                      25.0                      SOACHA
# 211939                      47.0                 SANTA MARTA
#
#         your_municipality_code_resides.1     your_area_residse  \
# 306                              19100.0            Rural area
# 308                              68081.0  Head of Municipality
# 362                              17001.0  Head of Municipality
# 429                              17001.0  Head of Municipality
# 438                                  NaN  Head of Municipality
# ...                                  ...                   ...
# 211405                            8001.0            Rural area
# 211406                           52001.0  Head of Municipality
# 211633                               NaN  Head of Municipality
# 211914                           25754.0            Rural area
# 211939                           47001.0  Head of Municipality
#
#                                  your_tuition your_times_took_exam  \
# 306                      Does not pay Pension                  NaN
# 308                      Does not pay Pension                  NaN
# 362                      Does not pay Pension                  NaN
# 429                      Does not pay Pension                  NaN
# 438                      Does not pay Pension                  NaN
# ...                                       ...                  ...
# 211405                   Does not pay Pension                  NaN
# 211406                   Does not pay Pension                  NaN
# 211633                       Less than 87,000                  NaN
# 211914  Between 150,000 and less than 250,000                  NaN
# 211939                   Does not pay Pension                  NaN
#
#             fami_father_education.1       fami_mother_education.1  \
# 306          Middle School complete  Elementary school incomplete
# 308                            None  Elementary school incomplete
# 362          Middle School complete      Middle School incomplete
# 429     Technical School incomplete        Middle School complete
# 438                             NaN                           NaN
# ...                             ...                           ...
# 211405       Middle School complete        Middle School complete
# 211406    Technical School complete               Graduate Degree
# 211633                          NaN                           NaN
# 211914     Middle School incomplete     Technical School complete
# 211939    Technical School complete        Middle School complete
#
#                              fami_father_occupation.1  \
# 306                                     Self-employed
# 308       Empleado de nivel auxiliar o administrativo
# 362                                         Pensioner
# 429       Empleado de nivel auxiliar o administrativo
# 438                                               NaN
# ...                                               ...
# 211405                                      Pensioner
# 211406                              Small businessman
# 211633                                            NaN
# 211914  Employee with technical level or professional
# 211939                                  Self-employed
#
#                              fami_mother_occupation.1 fami_housing_stratum.1  \
# 306                                     Self-employed              Stratum 1
# 308                                              Home              Stratum 1
# 362                                              Home              Stratum 3
# 429                                 Operator employee              Stratum 3
# 438                                               NaN                    NaN
# ...                                               ...                    ...
# 211405                                  Self-employed              Stratum 3
# 211406  Employee with technical level or professional              Stratum 2
# 211633                                            NaN                    NaN
# 211914                                  Self-employed              Stratum 3
# 211939                                           Home              Stratum 2
#
#        fami_social_stratum_sisben fami_house_members fami_house_rooms  \
# 306                       Level 1                Six             Four
# 308                       Level 2              Three              One
# 362      Not classified by SISBEN               Five            Three
# 429      Not classified by SISBEN               Five             Four
# 438                           NaN                NaN              NaN
# ...                           ...                ...              ...
# 211405   Not classified by SISBEN               Four              Two
# 211406   Not classified by SISBEN               Five             Four
# 211633                        NaN                NaN              NaN
# 211914   Not classified by SISBEN               Four            Three
# 211939   Not classified by SISBEN               Four              Two
#
#                                    fami_house_floor fami_internet.1  \
# 306                           Cement, gravel, brick              No
# 308     Polished wood, tile, tablet, marble, carpet              No
# 362                        Rough wood, board, plank              Si
# 429                        Rough wood, board, plank              Si
# 438                                             NaN             NaN
# ...                                             ...             ...
# 211405  Polished wood, tile, tablet, marble, carpet              Si
# 211406  Polished wood, tile, tablet, marble, carpet              Si
# 211633                                          NaN             NaN
# 211914  Polished wood, tile, tablet, marble, carpet              Si
# 211939                        Cement, gravel, brick              Si
#
#        fami_computer.1 fami_washer fami_microwave fami_oven fami_automobile.1  \
# 306                 No          No             No        No                No
# 308                 No          Si             No        Si                No
# 362                 Si          Si             Si        Si                No
# 429                 Si          Si             No        Si                No
# 438                NaN         NaN            NaN       NaN               NaN
# ...                ...         ...            ...       ...               ...
# 211405              Si          Si             No        No                Si
# 211406              Si          Si             Si        Si                No
# 211633             NaN         NaN            NaN       NaN               NaN
# 211914              Si          Si             Si        Si                Si
# 211939              Si          Si             No        No                No
#
#        fami_dvd fami_fridge.1 fami_mobile.1 fami_landline_phone.1  \
# 306          No            No            Si                    No
# 308          No            Si            Si                    No
# 362          Si            Si            Si                    Si
# 429          No            Si            Si                    Si
# 438         NaN           NaN           NaN                   NaN
# ...         ...           ...           ...                   ...
# 211405       Si            Si            Si                    Si
# 211406       Si            Si            Si                    Si
# 211633      NaN           NaN           NaN                   NaN
# 211914       Si            Si            Si                    Si
# 211939       Si            Si            Si                    Si
#
#        your_currently_working your_background your_expectations  \
# 306                        No              No               NaN
# 308                        No              No               NaN
# 362                        No              No               NaN
# 429                        No              No               NaN
# 438                       NaN              No               NaN
# ...                       ...             ...               ...
# 211405                     No              No               NaN
# 211406                     No              No               NaN
# 211633                    NaN              No               NaN
# 211914                     No              No               NaN
# 211939                     No              No               NaN
#
#         cole_code_icfes  cole_dane_code_establishment  \
# 306             11890.0                  1.526930e+11
# 308             14548.0                  1.680810e+11
# 362             42341.0                  1.170010e+11
# 429              6197.0                  1.170010e+11
# 438                 NaN                  1.630010e+11
# ...                 ...                           ...
# 211405           3590.0                  1.080010e+11
# 211406          11486.0                  1.520010e+11
# 211633              NaN                  3.680010e+11
# 211914           9258.0                  3.257540e+11
# 211939          10421.0                  2.470010e+11
#
#                                   cole_name_establishment cole_type  \
# 306     INSTITUCION  EDUCATIVA NORMAL SUPERIOR SAGRADO...     MIXED
# 308     INSTITUCION EDUCATIVA ESCUELA NORMAL SUPERIOR ...     MIXED
# 362     INSTITUCIÓN EDUCATIVA NACIONAL AUXILIARES DE E...     MIXED
# 429         INSTITUCIÓN EDUCATIVA NORMAL SUP DE MANIZALES     MIXED
# 438                               ESCUELA NORMAL SUPERIOR     MIXED
# ...                                                   ...       ...
# 211405  ESCUELA NORMAL SUPERIOR DEL DISTRITO DE BARRAN...     MIXED
# 211406                    I.E.M. NORMAL SUPERIOR DE PASTO     MIXED
# 211633                            COL  COLOMBO VENEZOLANO     MIXED
# 211914          ESCUELA NORMAL SUPERIOR MARIA AUXILIADORA     MIXED
# 211939  IED ESCUELA NORMAL SUPERIOR SAN PEDRO ALEJANDRINO     MIXED
#
#          cole_nature cole_calendar cole_bilingual      cole_character  \
# 306         OFFICIAL             A              N  TECHNICAL/ACADEMIC
# 308         OFFICIAL             A              N  TECHNICAL/ACADEMIC
# 362         OFFICIAL             A              N           TECHNICAL
# 429         OFFICIAL             A              N  TECHNICAL/ACADEMIC
# 438         OFFICIAL             A              N  TECHNICAL/ACADEMIC
# ...              ...           ...            ...                 ...
# 211405      OFFICIAL             A              N  TECHNICAL/ACADEMIC
# 211406      OFFICIAL             A              N  TECHNICAL/ACADEMIC
# 211633  NOT OFFICIAL             A              N            ACADEMIC
# 211914  NOT OFFICIAL             A              N  TECHNICAL/ACADEMIC
# 211939      OFFICIAL             A              N  TECHNICAL/ACADEMIC
#
#         cole_dane_code_campus  \
# 306              1.526930e+11
# 308              1.680810e+11
# 362              1.170010e+11
# 429              1.170010e+11
# 438              1.630010e+11
# ...                       ...
# 211405           1.080010e+11
# 211406           1.520010e+11
# 211633           3.680010e+11
# 211914           3.257540e+11
# 211939           2.470010e+11
#
#                                          cole_name_campus cole_main_campus  \
# 306              NORMAL SUPERIOR SAGRADO CORAZON DE JESUS              YES
# 308                    ESCUELA NORMAL SUPERIOR CRISTO REY              YES
# 362     INSTITUCIÓN EDUCATIVA NACIONAL AUXILIARES DE E...              YES
# 429         INSTITUCIÓN EDUCATIVA NORMAL SUP DE MANIZALES              YES
# 438                               ESCUELA NORMAL SUPERIOR              YES
# ...                                                   ...              ...
# 211405  ESCUELA NORMAL SUPERIOR DEL DISTRITO BARRANQUILLA              YES
# 211406   I.E.M. NORMAL SUPERIOR DE PASTO - SEDE PRINCIPAL              YES
# 211633                            COL  COLOMBO VENEZOLANO              YES
# 211914          ESCUELA NORMAL SUPERIOR MARIA AUXILIADORA              YES
# 211939               ESCUELA NORMAL SAN PEDRO ALEJANDRINO              YES
#
#        cole_area_location cole_journey  cole_municipality_code_location  \
# 306                 URBAN      MORNING                          52693.0
# 308                 URBAN      MORNING                          68081.0
# 362                 URBAN      MORNING                          17001.0
# 429                 URBAN      MORNING                          17001.0
# 438                 URBAN      MORNING                          63001.0
# ...                   ...          ...                              ...
# 211405              URBAN      MORNING                           8001.0
# 211406              URBAN      MORNING                          52001.0
# 211633              URBAN        NIGHT                          68001.0
# 211914              URBAN     COMPLETE                          25754.0
# 211939              URBAN     COMPLETE                          47001.0
#
#        cole_municipality_location  cole_dept_code_location cole_dept_location  \
# 306                     SAN PABLO                     52.0             NARIÑO
# 308               BARRANCABERMEJA                     68.0          SANTANDER
# 362                     MANIZALES                     17.0             CALDAS
# 429                     MANIZALES                     17.0             CALDAS
# 438                       ARMENIA                     63.0            QUINDIO
# ...                           ...                      ...                ...
# 211405               BARRANQUILLA                      8.0          ATLANTICO
# 211406                      PASTO                     52.0             NARIÑO
# 211633                BUCARAMANGA                     68.0          SANTANDER
# 211914                     SOACHA                     25.0       CUNDINAMARCA
# 211939                SANTA MARTA                     47.0          MAGDALENA
#
#         score_language  score_mathematics  score_biology  score_chemistry  \
# 306               48.0               39.0           43.0             47.0
# 308               59.0               55.0           57.0             54.0
# 362               53.0               61.0           61.0             49.0
# 429               53.0               58.0           48.0             46.0
# 438               44.0               52.0           40.0             40.0
# ...                ...                ...            ...              ...
# 211405            53.0               46.0           36.0             40.0
# 211406            53.0               58.0           54.0             47.0
# 211633            35.0               46.0           40.0             43.0
# 211914            53.0               49.0           48.0             48.0
# 211939            48.0               52.0           50.0             56.0
#
#         score_physical  score_social_science  score_philosophy  score_english  \
# 306               46.0                  44.0              39.0           39.0
# 308               53.0                  65.0              50.0           68.0
# 362               50.0                  52.0              61.0           77.0
# 429               40.0                  46.0              48.0           53.0
# 438               40.0                  44.0              43.0           39.0
# ...                ...                   ...               ...            ...
# 211405            35.0                  52.0              45.0           36.0
# 211406            43.0                  44.0              48.0           42.0
# 211633            40.0                  46.0              34.0           39.0
# 211914            46.0                  54.0              45.0           48.0
# 211939            50.0                  59.0              45.0           46.0
#
#        performance_english                           go_deep  score_prof  \
# 306                     A-       SCORE_DEEPEN_SOCIAL_SCIENCE         5.0
# 308                     B1  SCORE_INTERDISC_VIOLENCE_AND_SOC        63.0
# 362                     B1       SCORE_INTERDISC_ENVIRONMENT        58.0
# 429                     A2             SCORE_DEEPEN_LANGUAGE         6.0
# 438                     A-          SCORE_DEEPEN_MATHEMATICS         3.0
# ...                    ...                               ...         ...
# 211405                  A-       SCORE_INTERDISC_ENVIRONMENT        47.0
# 211406                  A-              SCORE_DEEPEN_BIOLOGY         6.0
# 211633                  A-       SCORE_INTERDISC_ENVIRONMENT        52.0
# 211914                  A1  SCORE_INTERDISC_VIOLENCE_AND_SOC        48.0
# 211939                  A1  SCORE_INTERDISC_VIOLENCE_AND_SOC        52.0
#
#        performance_prof  total_saber_score  total_saber_pro_score
# 306                   I              350.0                  43.70
# 308                 NaN              524.0                  59.70
# 362                 NaN              522.0                  59.88
# 429                   I              398.0                  50.40
# 438                  GB              345.0                  49.20
# ...                 ...                ...                    ...
# 211405              NaN              390.0                  45.90
# 211406                I              395.0                  48.40
# 211633              NaN              375.0                  45.70
# 211914              NaN              439.0                  50.30
# 211939              NaN              458.0                  46.40
#
# [2370 rows x 144 columns]

# %%
relevant_social_factors = ['your_course_teacher_ies', "your_course_external_support_ies", 'your_course_external_ies', 
                           'your_simulation_type_icfes', 'your_activity_strengths_generic', 'fami_housing_stratum', 'fami_internet',
                           'fami_computer', 'fami_automobile', 'fami_father_education', 'fami_mother_education',
                           'fami_father_occupation','fami_mother_occupation']

# %%
# Since fami mother and father work are all NaNs, use occupation instead

cols = 3
rows = len(relevant_social_factors) // cols+1
fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(30,30))
plt.subplots_adjust(hspace = 5.0)

axe=axs.ravel()

counter = 0

for i in relevant_social_factors:
    superior_normalist_saber_pro.groupby(superior_normalist_saber_pro[i])['total_saber_pro_score'].count().plot.bar(ax=axe[counter])
    counter += 1
# Out:
# c:\users\gerson cruz\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %% [markdown]
# ### Technical Bachelor

# %%
hs_degree = ['Technical Bachelor']
technical_bachelor_saber_pro = saber.loc[saber['your_high_school_degree'].isin(hs_degree)]

# %%
# Since fami mother and father work are all NaNs, use occupation instead

cols = 3
rows = len(relevant_social_factors) // cols+1
fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(30,30))
plt.subplots_adjust(hspace = 5.0)

axe=axs.ravel()

counter = 0

for i in relevant_social_factors:
    technical_bachelor_saber_pro.groupby(technical_bachelor_saber_pro[i])['total_saber_pro_score'].count().plot.bar(ax=axe[counter])
    counter += 1

# %% [markdown]
# ### Insights for Superior Normalist
#
# Similar to the insights generated for the bottom 50 municipalities with the exception that students from superior normalist schools have access to the internet, majority of students also did not take preparation tests and live on Stratum 1 housing. Furthermore, majority of their parents finished only up to Elementary and Middle School with the father being self-employed and the mother staying at home. These insights show similarities with the Bottom 50 Municipalities.
#
# ### Insights for Technical Bachelor
#
# Same with Superior Normalist except that majority of students with this high school degre live in Stratum 2 housing.
#
# ##### Additional question: Do the municipalities of these students belong to the Bottom 50?
# ##### Additional question for municipality analysis: What's the lowest score per municipality? Is there a consistent low score among Saber areas?

# %% [markdown]
# ### Next Step
#
# 1. Generate Insights for this
# 2. Think about how to generate visualizations for the undergraduate core and program academic level
#     2.1 Probably a question like: What's the mean score for every undergraduate core? Are there cores that student go to when they get low scores? Moreover, which municipalities do these low-scoring students come from?

# %% [markdown]
# #### Questions: What's the mean score for every undergraduate core? What are the characteristics of students who belong in the cores with highest and lowest scores?

# %%
print("There are {} unique undergraduate cores in this dataset".format(saber['your_undergraduate_core'].nunique()))
# Out:
# There are 63 unique undergraduate cores in this dataset

# %%
print("The top 10 undergraduate cores based on number of students are \n\n{}".format(saber['your_undergraduate_core'].value_counts().head(10)))
# Out:
# The top 10 undergraduate cores based on number of students are
#
# ADMINISTRATION                         35790
# LAW                                    15263
# PUBLIC ACCOUNTING                      14334
# EDUCATION                              14219
# INDUSTRIAL ENGINEERING                 10660
# PSYCHOLOGY                             10518
# ENVIRONMENTAL, SANITARY ENGINEERING     8231
# UNCLASSIFIED                            8091
# CIVIL ENGINEERING                       7736
# SOCIAL COMMUNICATION, JOURNALISM        7479
# Name: your_undergraduate_core, dtype: int64

# %% [markdown]
# Now let's examine the mean scores of students from every undergraduate core.

# %%
sorted_mean_undergraduate_core = saber.groupby("your_undergraduate_core")[total_marks].agg(["mean", "count"]).sort_values(by=("total_saber_pro_score", "mean"), ascending=False).reset_index()
sorted_mean_undergraduate_core
# Out:
#                              your_undergraduate_core total_saber_score         \
#                                                                   mean  count
# 0                                            PHISICS        528.387435    191
# 1         POLITICAL SCIENCE, INTERNATIONAL RELATIONS        479.516254   2061
# 2                         ANTHROPOLOGY, LIBERAL ARTS        485.922886    402
# 3          MODERN LANGUAGES, LITERATURE, LINGUISTICS        478.455865    827
# 4                                   MATH, STATISTICS        490.619898    392
# 5                                           MEDICINE        500.939942   2764
# 6                               CHEMICAL ENGINEERING        492.063681   1853
# 7                               PHILOSOPHY, THEOLOGY        465.083333    336
# 8                         ADMINISTRATIVE ENGINEERING        465.229901    709
# 9                             BIOMEDICAL ENGINEERING        463.157197    528
# 10                             BIOLOGY, MICROBIOLOGY        464.484132   1607
# 11                                               LAW        438.401494  15263
# 12                                NUTRITION AND DIET        438.306818    264
# 13                  AGROINDUSTRIAL ENGINEERING, FOOD        449.119403    469
# 14                              PLASTIC, VISUAL ARTS        457.840951    547
# 15                                             MUSIC        482.310811    444
# 16                                      BACTERIOLOGY        440.436573    607
# 17                                      ARCHITECTURE        453.720081   3969
# 18                                GEOGRAPHY, HISTORY        437.035556    675
# 19                AGRICULTURAL, FORESTRY ENGINEERING        450.563433    268
# 20                               VETERINARY MEDICINE        439.493036   1077
# 21                           NUTRITION AND DIETETICS        427.430769    325
# 22                  SOCIAL COMMUNICATION, JOURNALISM        435.071266   7479
# 23                                 CIVIL ENGINEERING        452.878490   7736
# 24                                        PSYCHOLOGY        422.851398  10518
# 25                                        ODONTOLOGY        422.665851    817
# 26                            ELECTRICAL ENGINEERING        465.816139    979
# 27                            INDUSTRIAL ENGINEERING        450.663884  10660
# 28                    MINING, METALLURGY ENGINEERING        483.299347   1226
# 29                                         THERAPIES        411.675728   2575
# 30                                           NURSING        411.531977   3440
# 31                         PLASTIC ARTS, VISUAL ARTS        461.390663    814
# 32                            SOCIOLOGY, SOCIAL WORK        407.695720   3832
# 33  TRAINING RELATED TO THE MILITARY OR POLICE FIELD        417.898810    168
# 34                               REPRESENTATIVE ARTS        450.457317    164
# 35                          SURGICAL INSTRUMENTATION        403.477099    786
# 36                                           ECONOMY        447.872152   7243
# 37                                         EDUCATION        405.748576  14219
# 38                                       ADVERTISING        428.266802    982
# 39                                 OTHER ENGINEERING        459.507143   1120
# 40                  AGRONOMIC, LIVESTOCK ENGINEERING        423.447263    749
# 41         SPORTS, PHYSICAL EDUCATION AND RECREATION        410.261402    899
# 42                                         CHEMISTRY        464.271605    972
# 43                                         DENTISTRY        424.774574    763
# 44        ELECTRONIC ENGINEERING, TELECOMMUNICATIONS        455.913533   2845
# 45          OPTOMETRY, OTHER HEALTH SCIENCE PROGRAMS        405.010989    273
# 46               AGROINDUSTRIAL AND FOOD ENGINEERING        437.027484    473
# 47                                            DESIGN        444.299449   5263
# 48                  AGRICULTURAL, FOREST ENGINEERING        437.217213    244
# 49           GEOLOGY, OTHER NATURAL SCIENCE PROGRAMS        473.916814    565
# 50                                    ADMINISTRATION        415.766778  35790
# 51               ENVIRONMENTAL, SANITARY ENGINEERING        423.633337   8231
# 52                            MECHANICAL ENGINEERING        439.887960   5382
# 53          OTHER PROGRAMS ASSOCIATED WITH FINE ARTS        423.709677    372
# 54                                 PUBLIC ACCOUNTING        406.540812  14334
# 55          COMPUTER SYSTEMS, TELEMATICS ENGINEERING        422.090228   6805
# 56                                         ZOOTECHNY        399.748677    756
# 57                                     PUBLIC HEALTH        386.750865   1156
# 58                       MILITARY OR POLICE TRAINING        390.819255   2202
# 59                                      UNCLASSIFIED        396.838339   8091
# 60                                  SUPERIOR NORMALS        387.223352   2655
# 61      LIBRARY, OTHERS OF SOCIAL AND HUMAN SCIENCES        386.150943    530
# 62                                          AGRONOMY        385.854525   1801
#
#    total_saber_pro_score
#                     mean  count
# 0             885.730524    191
# 1             875.952455   2061
# 2             872.131841    402
# 3             871.416203    827
# 4             869.198980    392
# 5             858.447739   2764
# 6             828.078370   1853
# 7             823.600893    336
# 8             821.858815    709
# 9             819.660966    528
# 10            809.480000   1607
# 11            789.474388  15263
# 12            786.958333    264
# 13            786.430704    469
# 14            784.910420    547
# 15            781.919167    444
# 16            778.002801    607
# 17            776.828884   3969
# 18            773.860741    675
# 19            773.444030    268
# 20            765.032126   1077
# 21            757.526154    325
# 22            757.250977   7479
# 23            754.936798   7736
# 24            753.435920  10518
# 25            749.110159    817
# 26            743.474045    979
# 27            741.511008  10660
# 28            738.602643   1226
# 29            737.195301   2575
# 30            724.581951   3440
# 31            724.340332    814
# 32            721.492873   3832
# 33            717.273810    168
# 34            715.325793    164
# 35            712.703053    786
# 36            711.153046   7243
# 37            700.987493  14219
# 38            695.030988    982
# 39            684.956330   1120
# 40            684.712310    749
# 41            675.609933    899
# 42            674.915679    972
# 43            666.319777    763
# 44            653.133926   2845
# 45            648.172601    273
# 46            614.323932    473
# 47            604.163580   5263
# 48            581.941434    244
# 49            581.626035    565
# 50            512.597000  35790
# 51            510.305410   8231
# 52            483.132066   5382
# 53            459.193763    372
# 54            452.819047  14334
# 55            441.025540   6805
# 56            387.603862    756
# 57            254.607535   1156
# 58            232.695159   2202
# 59            211.816553   8091
# 60            204.618606   2655
# 61            177.358868    530
# 62            104.525386   1801

# %%
top_10_undergraduate_cores_by_number = saber['your_undergraduate_core'].value_counts().head(10).index.to_list()

# %%
top_cores_rank = sorted_mean_undergraduate_core.loc[sorted_mean_undergraduate_core['your_undergraduate_core'].isin(top_10_undergraduate_cores_by_number)]
top_cores_rank.drop('total_saber_score', inplace=True, axis=1)
top_cores_rank
# Out:
# c:\users\gerson cruz\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# c:\users\gerson cruz\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                 your_undergraduate_core total_saber_pro_score
#                                                          mean  count
# 11                                  LAW            789.474388  15263
# 22     SOCIAL COMMUNICATION, JOURNALISM            757.250977   7479
# 23                    CIVIL ENGINEERING            754.936798   7736
# 24                           PSYCHOLOGY            753.435920  10518
# 27               INDUSTRIAL ENGINEERING            741.511008  10660
# 37                            EDUCATION            700.987493  14219
# 50                       ADMINISTRATION            512.597000  35790
# 51  ENVIRONMENTAL, SANITARY ENGINEERING            510.305410   8231
# 54                    PUBLIC ACCOUNTING            452.819047  14334
# 59                         UNCLASSIFIED            211.816553   8091

# %% [markdown]
# We see in the charts about that the top 10 undergraduate cores do not even belong to the cores in which students had the highest mean saber scores. Why?

# %% [markdown]
# ##### Question: In which municipalities do these students who take up the top 10 undergraduate cores live in?

# %%
saber[['your_municipality_resides', 'your_undergraduate_core']]
# Out:
#        your_municipality_resides      your_undergraduate_core
# 0                       GUATEQUE            PUBLIC ACCOUNTING
# 1                        LETICIA  MILITARY OR POLICE TRAINING
# 2                   DOSQUEBRADAS            PUBLIC ACCOUNTING
# 3            CARTAGENA DE INDIAS                      ECONOMY
# 4                         SOACHA               ADMINISTRATION
# ...                          ...                          ...
# 212005                  VALENCIA            CIVIL ENGINEERING
# 212006               BOGOTÁ D.C.                     MEDICINE
# 212007                   CORINTO               ADMINISTRATION
# 212008             VILLAVICENCIO       INDUSTRIAL ENGINEERING
# 212009                      CALI                    THERAPIES
#
# [212010 rows x 2 columns]

# %%
saber_pro_top_10_undergraduate_cores = saber.loc[saber['your_undergraduate_core'].isin(top_10_undergraduate_cores_by_number)]
saber_pro_top_10_undergraduate_cores.shape
# Out:
# (132321, 144)

# %%
top_10_undergraduate_cores_by_municipality = saber.groupby(['your_undergraduate_core', 'your_municipality_resides'])['total_saber_pro_score'].count()

# %%
saber.groupby(['your_undergraduate_core', 'your_municipality_resides'])['total_saber_pro_score'].size()
# Out:
# your_undergraduate_core  your_municipality_resides
# ADMINISTRATION           ABEJORRAL                     4
#                          ACACÍAS                      28
#                          ACEVEDO                       2
#                          ACHÍ                          3
#                          AGRADO                        4
#                                                       ..
# ZOOTECHNY                VILLAVICENCIO                 5
#                          VILLAVIEJA                    1
#                          YUMBO                         1
#                          ZIPAQUIRÁ                     2
#                          ÁBREGO                        1
# Name: total_saber_pro_score, Length: 10995, dtype: int64

# %%
top_10_undergraduate_cores_by_municipality['ADMINISTRATION'].sort_values(ascending=False).head(10).index
# Out:
# Index(['BOGOTÁ D.C.', 'BOGOTÁ, D.C.', 'MEDELLÍN', 'CALI', 'BARRANQUILLA',
#        'CARTAGENA DE INDIAS', 'IBAGUÉ', 'PEREIRA', 'BUCARAMANGA', 'MANIZALES'],
#       dtype='object', name='your_municipality_resides')

# %%
for i in top_10_undergraduate_cores_by_number: 
    plt.figure()
    sns.barplot(x = top_10_undergraduate_cores_by_municipality[i].sort_values(ascending=False).head(10).index,  
                y=top_10_undergraduate_cores_by_municipality[i].sort_values(ascending=False).head(10).values)
    plt.xticks(rotation=90)
    plt.title(i)

# %%
for i in top_10_undergraduate_cores_by_number:    
    # Checking for intersection between sets
    set1 = set(top_10_undergraduate_cores_by_municipality[i].sort_values(ascending=False).head(10).index.to_list()) 
    intersection = set1.intersection(saber_pro_bot_50_municipalities)
    intersection_list = list(intersection)
    print("\nOut of the top 10 municipalities for {}, {} municipalities belong to the bottom 50 of saber pro scores".format(i, len(intersection_list)))
# Out:
# Out of the top 10 municipalities for ADMINISTRATION, 0 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for LAW, 0 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for PUBLIC ACCOUNTING, 0 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for EDUCATION, 0 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for INDUSTRIAL ENGINEERING, 0 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for PSYCHOLOGY, 0 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for ENVIRONMENTAL, SANITARY ENGINEERING, 0 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for UNCLASSIFIED, 0 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for CIVIL ENGINEERING, 0 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for SOCIAL COMMUNICATION, JOURNALISM, 0 municipalities belong to the bottom 50 of saber pro scores

# %% [markdown]
# It is very interesting to note that no municipalities belonging in the top 10 by undergraduate core by number belong to the bottom 50!

# %%
for i in top_10_undergraduate_cores_by_number:    
    # Checking for intersection between sets
    set1 = set(top_10_undergraduate_cores_by_municipality[i].sort_values(ascending=False).head(10).index.to_list()) 
    intersection = set1.intersection(saber_pro_top_50_municipalities)
    intersection_list = list(intersection)
    print("\nOut of the top 10 municipalities for {}, {} municipalities belong to the bottom 50 of saber pro scores".format(i, len(intersection_list)))
# Out:
# Out of the top 10 municipalities for ADMINISTRATION, 3 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for LAW, 4 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for PUBLIC ACCOUNTING, 3 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for EDUCATION, 4 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for INDUSTRIAL ENGINEERING, 3 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for PSYCHOLOGY, 3 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for ENVIRONMENTAL, SANITARY ENGINEERING, 1 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for UNCLASSIFIED, 2 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for CIVIL ENGINEERING, 4 municipalities belong to the bottom 50 of saber pro scores
#
# Out of the top 10 municipalities for SOCIAL COMMUNICATION, JOURNALISM, 4 municipalities belong to the bottom 50 of saber pro scores

# %% [markdown]
# #### Rather, some of these municipalities belong to the municipalities who supposedly has the highest scores in Saber Pro!
#
# ##### Question: Why are students going to an undergraduate score with low mean Saber Pro scores when they belong to the municipalities that rank in the Top 50 in terms of Saber Pro scores?
